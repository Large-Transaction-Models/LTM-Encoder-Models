# %%
import os
import sys
sys.path.append(os.path.abspath('../'))
from dataset.aave_preload import AavePreloadDataset
import os.path as path
import logging
from dataset.vocab import *

# Configure logging for better debugging information
logging.basicConfig(level=logging.INFO,  
                    format='%(asctime)s - %(levelname)s - %(message)s')  
log = logging.getLogger(__name__)

# %%
include_user_features = True
include_time_features = True
include_market_features = True
include_exo_features = False

fextension = ""
if include_user_features:
    fextension += "_user"
if include_market_features:
    fextension += "_market"
if include_time_features:
    fextension += "_time"
if include_exo_features:
    fextension += "_exoLagged"

# %%
# Root and file configurations
root = "/data/IDEA_DeFi_Research/LTM/Data/Lending_Protocols/Aave/V2/Mainnet"  
fname = f"transactions{fextension}_train"  
val_fname = "" 
test_fname = f"transactions{fextension}_test"  
fextension = ""  # Use empty string instead of False to avoid confusion
vocab_dir = "vocab/"
cached = False
val_cached = False
test_cached = False
vocab_cached = False
encoder_cached = False
external_encoder_path = False  # Initialize as empty string for consistency

# Ensure fextension and external_encoder_path are strings
fextension = fextension if fextension else ""
external_encoder_path = external_encoder_path if external_encoder_path else ""

# Class name of the dataset to be instantiated
dataset_class = "AavePreloadDataset"

# Instantiate the dataset for preloading
dataset = eval(dataset_class)(
    num_bins=10,
    cached=False,  # Set as False to force reloading for the first run
    encoder_cached=False,
    external_encoder_path=external_encoder_path,
    vocab_cached=False,
    root=root,
    fname=fname,
    vocab_dir=vocab_dir,
    fextension=fextension,
    nrows=None,
    adap_thres=10 ** 8,
    get_rids=True,
    columns_to_select=None
)

# Print out vocab sizes for verification
print(len(dataset.dynamic_vocab), len(dataset.time_feature_vocab), len(dataset.static_vocab))
# Out:
# /home/greena12/LTM-Encoder-Models/dataset/aave_preload.py:281: DtypeWarning: Columns (11,12,13,14,16,20,21) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv(fname, nrows=self.nrows)
# 2025-01-22 14:06:52,681 - INFO - read data : (1921610, 128)
# 2025-01-22 14:06:52,682 - INFO - /data/IDEA_DeFi_Research/LTM/Data/Lending_Protocols/Aave/V2/Mainnet/transactions_user_market_time_train.csv is read.
# 2025-01-22 14:06:52,682 - INFO - nan resolution.
# 2025-01-22 14:06:57,664 - INFO - timestamp fit transform
# 2025-01-22 14:06:57,665 - INFO - label-fit-transform.
#  41%|████      | 7/17 [00:02<00:02,  3.42it/s]2025-01-22 14:06:59,746 - INFO - skipping col user
# 2025-01-22 14:06:59,746 - INFO - skipping col id
# 100%|██████████| 17/17 [00:03<00:00,  4.35it/s]
# 2025-01-22 14:07:01,576 - INFO - amount quant transform
#   0%|          | 0/111 [00:00<?, ?it/s]2025-01-22 14:07:01,578 - INFO - skipping col rowNumber
# 2025-01-22 14:07:01,578 - INFO - skipping col timestamp
# 100%|██████████| 111/111 [00:05<00:00, 18.58it/s]
# 2025-01-22 14:07:08,285 - INFO - writing cached csv to /data/IDEA_DeFi_Research/LTM/Data/Lending_Protocols/Aave/V2/Mainnet/preprocessed/transactions_user_market_time_train.encoded.csv
# 2025-01-22 14:07:08,288 - INFO - writing to file /data/IDEA_DeFi_Research/LTM/Data/Lending_Protocols/Aave/V2/Mainnet/preprocessed/transactions_user_market_time_train.encoded.csv
# 2025-01-22 14:07:49,634 - INFO - writing cached encoder fit to /data/IDEA_DeFi_Research/LTM/Data/Lending_Protocols/Aave/V2/Mainnet/preprocessed/transactions_user_market_time_train.encoder_fit.pkl
# 2025-01-22 14:07:49,658 - INFO - starting with 128 columns
# 2025-01-22 14:07:50,551 - INFO - total columns: ['rowNumber', 'user', 'timestamp', 'id', 'borrowRateModeFrom', 'borrowRateModeTo', 'cosDayOfMonth', 'isWeekend', 'marketBorrowAvgAmountETH', 'cosDayOfYear', 'collateralReserve', 'reserve', 'marketLiquidationAvgAmount', 'marketWithdrawSumUSD', 'marketDepositSumUSD', 'dayOfWeek', 'marketRepayAvgAmountETH', 'marketCollateralCount', 'sinTimeOfDay', 'sinDayOfMonth', 'liquidator', 'marketBorrowSumUSD', 'type', 'cosDayOfWeek', 'sinDayOfYear', 'marketWithdrawSumETH', 'amountETH', 'borrowRateMode', 'marketLiquidationAvgAmountETH', 'marketDepositAvgAmountUSD', 'sinQuarter', 'amount', 'stableBorrowRate', 'Year', 'sinDayOfQuarter', 'collateralAmount', 'coinType', 'priceInUSD', 'marketRepayAvgAmount', 'cosTimeOfDay', 'toState', 'marketSwapCount', 'marketRepayCount', 'quarter', 'marketWithdrawCount', 'sinDayOfWeek', 'collateralAmountUSD', 'marketDepositSumETH', 'fromState', 'marketBorrowSumETH', 'marketLiquidationSumETH', 'cosQuarter', 'dayOfYear', 'marketBorrowSum', 'marketLiquidationSum', 'marketRepayAvgAmountUSD', 'amountUSD', 'marketWithdrawAvgAmountETH', 'marketWithdrawSum', 'marketBorrowAvgAmountUSD', 'marketDepositAvgAmountETH', 'collateralAmountETH', 'marketDepositAvgAmount', 'marketBorrowCount', 'marketLiquidationCount', 'marketLiquidationSumUSD', 'marketRepaySumUSD', 'marketRepaySum', 'dayOfMonth', 'marketBorrowAvgAmount', 'variableBorrowRate', 'marketLiquidationAvgAmountUSD', 'cosDayOfQuarter', 'pool', 'timeOfDay', 'marketDepositSum', 'dayOfQuarter', 'marketWithdrawAvgAmountUSD', 'borrowRate', 'marketDepositCount', 'marketWithdrawAvgAmount', 'marketRepaySumETH', 'timeFeature', 'userDepositSumUSD', 'userRepaySum', 'userActiveDaysWeekly', 'userBorrowSumETH', 'userWithdrawAvgAmount', 'userRepaySumETH', 'userWithdrawSumUSD', 'userBorrowAvgAmountETH', 'userActiveDaysMonthly', 'userLiquidationSumETH', 'userLiquidationAvgAmountETH', 'userWithdrawCount', 'userWithdrawAvgAmountETH', 'userCollateralCount', 'userBorrowCount', 'userLiquidationCount', 'userWithdrawAvgAmountUSD', 'userSwapCount', 'userRepaySumUSD', 'userSecondsSinceFirstTransaction', 'userBorrowAvgAmountUSD', 'userBorrowSumUSD', 'userReserveMode', 'userLiquidationAvgAmountUSD', 'userDepositAvgAmountETH', 'userRepayAvgAmount', 'userWithdrawSum', 'userLiquidationSum', 'userBorrowSum', 'userWithdrawSumETH', 'userSecondsSincePreviousTransaction', 'userDepositAvgAmount', 'userRepayAvgAmountUSD', 'userRepayCount', 'userIsNew', 'userDepositSumETH', 'userDepositSum', 'userDepositAvgAmountUSD', 'userLiquidationAvgAmount', 'userCoinTypeMode', 'userLiquidationSumUSD', 'userActiveDaysYearly', 'userDepositCount', 'userBorrowAvgAmount', 'userRepayAvgAmountETH'], total dynamic columns: ['borrowRateModeFrom', 'borrowRateModeTo', 'cosDayOfMonth', 'isWeekend', 'marketBorrowAvgAmountETH', 'cosDayOfYear', 'collateralReserve', 'reserve', 'marketLiquidationAvgAmount', 'marketWithdrawSumUSD', 'marketDepositSumUSD', 'dayOfWeek', 'marketRepayAvgAmountETH', 'marketCollateralCount', 'sinTimeOfDay', 'sinDayOfMonth', 'liquidator', 'marketBorrowSumUSD', 'type', 'cosDayOfWeek', 'sinDayOfYear', 'marketWithdrawSumETH', 'amountETH', 'borrowRateMode', 'marketLiquidationAvgAmountETH', 'marketDepositAvgAmountUSD', 'sinQuarter', 'amount', 'stableBorrowRate', 'Year', 'sinDayOfQuarter', 'collateralAmount', 'coinType', 'priceInUSD', 'marketRepayAvgAmount', 'cosTimeOfDay', 'toState', 'marketSwapCount', 'marketRepayCount', 'quarter', 'marketWithdrawCount', 'sinDayOfWeek', 'collateralAmountUSD', 'marketDepositSumETH', 'fromState', 'marketBorrowSumETH', 'marketLiquidationSumETH', 'cosQuarter', 'dayOfYear', 'marketBorrowSum', 'marketLiquidationSum', 'marketRepayAvgAmountUSD', 'amountUSD', 'marketWithdrawAvgAmountETH', 'marketWithdrawSum', 'marketBorrowAvgAmountUSD', 'marketDepositAvgAmountETH', 'collateralAmountETH', 'marketDepositAvgAmount', 'marketBorrowCount', 'marketLiquidationCount', 'marketLiquidationSumUSD', 'marketRepaySumUSD', 'marketRepaySum', 'dayOfMonth', 'market ...
# 2025-01-22 14:07:50,552 - INFO - total dynamic vocabulary size: 1208, total time feature vocabulary size: 18, total static vocabulary size: 520
# 2025-01-22 14:07:50,553 - INFO - column : borrowRateModeFrom, vocab size : 4
# 2025-01-22 14:07:50,553 - INFO - column : borrowRateModeTo, vocab size : 4
# 2025-01-22 14:07:50,554 - INFO - column : cosDayOfMonth, vocab size : 9
# 2025-01-22 14:07:50,554 - INFO - column : isWeekend, vocab size : 3
# 2025-01-22 14:07:50,554 - INFO - column : marketBorrowAvgAmountETH, vocab size : 11
# 2025-01-22 14:07:50,555 - INFO - column : cosDayOfYear, vocab size : 11
# 2025-01-22 14:07:50,555 - INFO - column : collateralReserve, vocab size : 40
# 2025-01-22 14:07:50,555 - INFO - column : reserve, vocab size : 61
# 2025-01-22 14:07:50,556 - INFO - column : marketLiquidationAvgAmount, vocab size : 11
# 2025-01-22 14:07:50,556 - INFO - column : marketWithdrawSumUSD, vocab size : 11
# 2025-01-22 14:07:50,557 - INFO - column : marketDepositSumUSD, vocab size : 11
# 2025-01-22 14:07:50,557 - INFO - column : dayOfWeek, vocab size : 8
# 2025-01-22 14:07:50,557 - INFO - column : marketRepayAvgAmountETH, vocab size : 11
# 2025-01-22 14:07:50,558 - INFO - column : marketCollateralCount, vocab size : 11
# 2025-01-22 14:07:50,558 - INFO - column : sinTimeOfDay, vocab size : 11
# 2025-01-22 14:07:50,558 - INFO - column : sinDayOfMonth, vocab size : 10
# 2025-01-22 14:07:50,559 - INFO - column : liquidator, vocab size : 381
# 2025-01-22 14:07:50,559 - INFO - column : marketBorrowSumUSD, vocab size : 11
# 2025-01-22 14:07:50,560 - INFO - column : type, vocab size : 8
# 2025-01-22 14:07:50,560 - INFO - column : cosDayOfWeek, vocab size : 5
# 2025-01-22 14:07:50,560 - INFO - column : sinDayOfYear, vocab size : 11
# 2025-01-22 14:07:50,561 - INFO - column : marketWithdrawSumETH, vocab size : 11
# 2025-01-22 14:07:50,561 - INFO - column : amountETH, vocab size : 11
# 2025-01-22 14:07:50,561 - INFO - column : borrowRateMode, vocab size : 4
# 2025-01-22 14:07:50,562 - INFO - column : marketLiquidationAvgAmountETH, vocab size : 11
# 2025-01-22 14:07:50,562 - INFO - column : marketDepositAvgAmountUSD, vocab size : 11
# 2025-01-22 14:07:50,563 - INFO - column : sinQuarter, vocab size : 4
# 2025-01-22 14:07:50,563 - INFO - column : amount, vocab size : 11
# 2025-01-22 14:07:50,563 - INFO - column : stableBorrowRate, vocab size : 11
# 2025-01-22 14:07:50,564 - INFO - column : Year, vocab size : 5
# 2025-01-22 14:07:50,564 - INFO - column : sinDayOfQuarter, vocab size : 11
# 2025-01-22 14:07:50,564 - INFO - column : collateralAmount, vocab size : 11
# 2025-01-22 14:07:50,565 - INFO - column : coinType, vocab size : 3
# 2025-01-22 14:07:50,565 - INFO - column : priceInUSD, vocab size : 11
# 2025-01-22 14:07:50,565 - INFO - column : marketRepayAvgAmount, vocab size : 11
# 2025-01-22 14:07:50,566 - INFO - column : cosTimeOfDay, vocab size : 11
# 2025-01-22 14:07:50,566 - INFO - column : toState, vocab size : 4
# 2025-01-22 14:07:50,567 - INFO - column : marketSwapCount, vocab size : 11
# 2025-01-22 14:07:50,567 - INFO - column : marketRepayCount, vocab size : 11
# 2025-01-22 14:07:50,567 - INFO - column : quarter, vocab size : 5
# 2025-01-22 14:07:50,568 - INFO - column : marketWithdrawCount, vocab size : 11
# 2025-01-22 14:07:50,568 - INFO - column : sinDayOfWeek, vocab size : 5
# 2025-01-22 14:07:50,568 - INFO - column : collateralAmountUSD, vocab size : 11
# 2025-01-22 14:07:50,569 - INFO - column : marketDepositSumETH, vocab size : 11
# 2025-01-22 14:07:50,569 - INFO - column : fromState, vocab size : 4
# 2025-01-22 14:07:50,570 - INFO - column : marketBorrowSumETH, vocab size : 11
# 2025-01-22 14:07:50,570 - INFO - column : marketLiquidationSumETH, vocab size : 11
# 2025-01-22 14:07:50,570 - INFO - column : cosQuarter, vocab size : 4
# 2025-01-22 14:07:50,571 - INFO - column : dayOfYear, vocab size : 11
# 2025-01-22 14:07:50,571 - INFO - column : marketBorrowSum, vocab size : 11
# 2025-01-22 14:07:50,571 - INFO - column : marketLiquidationSum, vocab size : 11
# 2025-01-22 14:07:50,572 - INFO - column : marketRepayAvgAmountUSD, vocab size : 11
# 2025-01-22 14:07:50,572 - INFO - column : amountUSD, vocab size : 11
# 2025-01-22 14:07:50,572 - INFO - column : marketWithdrawAvgAmountETH, vocab size : 11
# 2025-01-22 14:07:50,573 - INFO - column : marketWithdrawSum, vocab size : 11
# 2025-01-22 14:07:50,573 - INFO - column : marketBorrowAvgAmountUSD, vocab size : 11
# 2025-01-22 14:07:50,574 - INFO - column : marketDepositAvgAmountETH, vocab size : 11
# 2025-01-22 14:07:50,574 - INFO - column : collateralAmountETH, vocab size : 11
# 2025-01-22 14:07:50,574 - INFO - column : marketDepositAvgAmount, vocab size : 11
# 2025-01-22 14:07:50,575 - INFO - column : marketBorrowCount, vocab size : 11
# 2025-01-22 14:07:50,575 - INFO - column : marketLiquidationCount, vocab size : 11
# 2025-01-22 14:07:50,575 - INFO - column : marketLiquidationSumUSD, vocab size : 11
# 2025-01-22 14:07:50,576 - INFO - column : marketRepaySumUSD, vocab size : 11
# 2025-01-22 14:07:50,581 - INFO - column : marketRepaySum, vocab size : 11
# 2025-01-22 14:07:50,581 - INFO - column : dayOfMonth, vocab size : 11
# 2025-01-22 14:07:50,581 - INFO - column : marketBorrowAvgAmount, vocab size : 11
# 2025-01-22 14:07:50,582 - INFO - column : variableBorrowRate, vocab size : 11
# 2025-01-22 14:07:50,582 - INFO - column : marketLiquidationAvgAmountUSD, vocab size : 11
# 2025-01-22 14:07:50,582 - INFO - column : cosDayOfQuarter, vocab size : 11
# 2025-01-22 14:07:50,582 - INFO - column : pool, vocab size : 3
# 2025-01-22 14:07:50,583 - INFO - column : timeOfDay, vocab size : 11
# 2025-01-22 14:07:50,583 - INFO - column : marketDepositSum, vocab size : 11
# 2025-01-22 14:07:50,583 - INFO - column : dayOfQuarter, vocab size : 11
# 2025-01-22 14:07:50,584 - INFO - column : marketWithdrawAvgAmountUSD, vocab size : 11
# 2025-01-22 14:07:50,584 - INFO - column : borrowRate, vocab size : 11
# 2025-01-22 14:07:50,584 - INFO - column : marketDepositCount, vocab size : 11
# 2025-01-22 14:07:50,585 - INFO - column : marketWithdrawAvgAmount, vocab size : 11
# 2025-01-22 14:07:50,585 - INFO - column : marketRepaySumETH, vocab size : 11
# 2025-01-22 14:07:50,585 - INFO - column : SPECIAL, vocab size : 7
# 2025-01-22 14:07:50,586 - INFO - column : timeFeature, vocab size : 11
# 2025-01-22 14:07:50,587 - INFO - column : SPECIAL, vocab size : 7
# 2025-01-22 14:07:50,587 - INFO - column : userDepositSumUSD, vocab size : 11
# 2025-01-22 14:07:50,588 - INFO - column : userRepaySum, vocab size : 11
# 2025-01-22 14:07:50,588 - INFO - column : userActiveDaysWeekly, vocab size : 6
# 2025-01-22 14:07:50,588 - INFO - column : userBorrowSumETH, vocab size : 11
# 2025-01-22 14:07:50,589 - INFO - column : userWithdrawAvgAmount, vocab size : 11
# 2025-01-22 14:07:50,589 - INFO - column : userRepaySumETH, vocab size : 11
# 2025-01-22 14:07:50,589 - INFO - column : userWithdrawSumUSD, vocab size : 11
# 2025-01-22 14:07:50,590 - INFO - column : userBorrowAvgAmountETH, vocab size : 11
# 2025-01-22 14:07:50,591 - INFO - column : userActiveDaysMonthly, vocab size : 9
# 2025-01-22 14:07:50,591 - INFO - column : userLiquidationSumETH, vocab size : 11
# 2025-01-22 14:07:50,591 - INFO - column : userLiquidationAvgAmountETH, vocab size : 11
# 2025-01-22 14:07:50,592 - INFO - column : userWithdrawCount, vocab size : 11
# 2025-01-22 14:07:50,592 - INFO - column : userWithdrawAvgAmountETH, vocab size : 11
# 2025-01-22 14:07:50,592 - INFO - column : userCollateralCount, vocab size : 10
# 2025-01-22 14:07:50,593 - INFO - column : userBorrowCount, vocab size : 11
# 2025-01-22 14:07:50,593 - INFO - column : userLiquidationCount, vocab size : 8
# 2025-01-22 14:07:50,593 - INFO - column : userWithdrawAvgAmountUSD, vocab size : 11
# 2025-01-22 14:07:50,594 - INFO - column : userSwapCount, vocab size : 7
# 2025-01-22 14:07:50,594 - INFO - column : userRepaySumUSD, vocab size : 11
# 2025-01-22 14:07:50,594 - INFO - column : userSecondsSinceFirstTransaction, vocab size : 11
# 2025-01-22 14:07:50,595 - INFO - column : userBorrowAvgAmountUSD, vocab size : 11
# 2025-01-22 14:07:50,595 - INFO - column : userBorrowSumUSD, vocab size : 11
# 2025-01-22 14:07:50,595 - INFO - column : userReserveMode, vocab size : 61
# 2025-01-22 14:07:50,595 - INFO - column : userLiquidationAvgAmountUSD, vocab size : 11
# 2025-01-22 14:07:50,596 - INFO - column : userDepositAvgAmountETH, vocab size : 11
# 2025-01-22 14:07:50,596 - INFO - column : userRepayAvgAmount, vocab size : 11
# 2025-01-22 14:07:50,596 - INFO - column : userWithdrawSum, vocab size : 11
# 2025-01-22 14:07:50,597 - INFO - column : userLiquidationSum, vocab size : 11
# 2025-01-22 14:07:50,597 - INFO - column : userBorrowSum, vocab size : 11
# 2025-01-22 14:07:50,597 - INFO - column : userWithdrawSumETH, vocab size : 11
# 2025-01-22 14:07:50,598 - INFO - column : userSecondsSincePreviousTransaction, vocab size : 11
# 2025-01-22 14:07:50,598 - INFO - column : userDepositAvgAmount, vocab size : 11
# 2025-01-22 14:07:50,598 - INFO - column : userRepayAvgAmountUSD, vocab size : 11
# 2025-01-22 14:07:50,599 - INFO - column : userRepayCount, vocab size : 11
# 2025-01-22 14:07:50,599 - INFO - column : userIsNew, vocab size : 3
# 2025-01-22 14:07:50,599 - INFO - column : userDepositSumETH, vocab size : 11
# 2025-01-22 14:07:50,599 - INFO - column : userDepositSum, vocab size : 11
# 2025-01-22 14:07:50,600 - INFO - column : userDepositAvgAmountUSD, vocab size : 11
# 2025-01-22 14:07:50,600 - INFO - column : userLiquidationAvgAmount, vocab size : 11
# 2025-01-22 14:07:50,600 - INFO - column : userCoinTypeMode, vocab size : 3
# 2025-01-22 14:07:50,601 - INFO - column : userLiquidationSumUSD, vocab size : 11
# 2025-01-22 14:07:50,601 - INFO - column : userActiveDaysYearly, vocab size : 10
# 2025-01-22 14:07:50,601 - INFO - column : userDepositCount, vocab size : 11
# 2025-01-22 14:07:50,602 - INFO - column : userBorrowAvgAmount, vocab size : 11
# 2025-01-22 14:07:50,602 - INFO - column : userRepayAvgAmountETH, vocab size : 11
# 2025-01-22 14:07:50,602 - INFO - column : SPECIAL, vocab size : 7
# 2025-01-22 14:07:50,602 - INFO - saving vocab at /data/IDEA_DeFi_Research/LTM/Data/Lending_Protocols/Aave/V2/Mainnet/vocab/dynamic_vocab.nb
# 2025-01-22 14:07:50,613 - INFO - saving vocab object at /data/IDEA_DeFi_Research/LTM/Data/Lending_Protocols/Aave/V2/Mainnet/vocab/dynamic_vocab_ob
# 2025-01-22 14:07:50,613 - INFO - saving vocab at /data/IDEA_DeFi_Research/LTM/Data/Lending_Protocols/Aave/V2/Mainnet/vocab/time_feature_vocab.nb
# 2025-01-22 14:07:50,619 - INFO - saving vocab object at /data/IDEA_DeFi_Research/LTM/Data/Lending_Protocols/Aave/V2/Mainnet/vocab/time_feature_vocab_ob
# 2025-01-22 14:07:50,619 - INFO - saving vocab at /data/IDEA_DeFi_Research/LTM/Data/Lending_Protocols/Aave/V2/Mainnet/vocab/static_vocab.nb
# 2025-01-22 14:07:50,625 - INFO - saving vocab object at /data/IDEA_DeFi_Research/LTM/Data/Lending_Protocols/Aave/V2/Mainnet/vocab/static_vocab_ob
# 1208 18 520

# %%
# If the encoder wasn't cached before, set the external path to the newly generated encoder
if not encoder_cached:
    print(f"dataset.encoder_path: {dataset.encoder_path}")
    external_encoder_path = dataset.encoder_path
    
# Update flags indicating caching is now done
vocab_cached = True
encoder_cached = True

test_dataset = eval(dataset_class)(
    num_bins=10,
    cached=False,  # Disable cached to generate fresh encoded data
    encoder_cached=encoder_cached,  # Force generation of a new encoder if missing
    external_encoder_path=external_encoder_path,  # Should be empty or point to existing encoder
    vocab_cached=vocab_cached,
    root=root,
    fname=test_fname,
    vocab_dir=vocab_dir,
    fextension=fextension,
    nrows=None,
    adap_thres=10 ** 8,
    get_rids=True,
    columns_to_select=None
)

# Print out vocab sizes for the test dataset to ensure consistency
print(len(test_dataset.dynamic_vocab), len(test_dataset.time_feature_vocab), len(test_dataset.static_vocab))
# Out:
# 2025-01-22 14:07:50,631 - INFO - cached encoder is read from /data/IDEA_DeFi_Research/LTM/Data/Lending_Protocols/Aave/V2/Mainnet/preprocessed/transactions_user_market_time_train.encoder_fit.pkl
# dataset.encoder_path: /data/IDEA_DeFi_Research/LTM/Data/Lending_Protocols/Aave/V2/Mainnet/preprocessed/transactions_user_market_time_train.encoder_fit.pkl
# 2025-01-22 14:07:52,934 - INFO - read data : (87566, 128)
# 2025-01-22 14:07:52,935 - INFO - /data/IDEA_DeFi_Research/LTM/Data/Lending_Protocols/Aave/V2/Mainnet/transactions_user_market_time_test.csv is read.
# 2025-01-22 14:07:52,936 - INFO - nan resolution.
# 2025-01-22 14:07:53,165 - INFO - timestamp fit transform
# 2025-01-22 14:07:53,166 - INFO - label-fit-transform.
#  29%|██▉       | 5/17 [00:00<00:00, 39.15it/s]2025-01-22 14:07:53,333 - INFO - skipping col user
# 2025-01-22 14:07:53,334 - INFO - skipping col id
# 100%|██████████| 17/17 [00:00<00:00, 58.93it/s]
# 2025-01-22 14:07:53,457 - INFO - amount quant transform
#   0%|          | 0/111 [00:00<?, ?it/s]2025-01-22 14:07:53,459 - INFO - skipping col rowNumber
# 2025-01-22 14:07:53,459 - INFO - skipping col timestamp
# 100%|██████████| 111/111 [00:00<00:00, 616.28it/s]
# 2025-01-22 14:07:53,681 - INFO - writing cached csv to /data/IDEA_DeFi_Research/LTM/Data/Lending_Protocols/Aave/V2/Mainnet/preprocessed/transactions_user_market_time_test.encoded.csv
# 2025-01-22 14:07:53,682 - INFO - writing to file /data/IDEA_DeFi_Research/LTM/Data/Lending_Protocols/Aave/V2/Mainnet/preprocessed/transactions_user_market_time_test.encoded.csv
# 2025-01-22 14:07:55,935 - INFO - writing cached encoder fit to /data/IDEA_DeFi_Research/LTM/Data/Lending_Protocols/Aave/V2/Mainnet/preprocessed/transactions_user_market_time_test.encoder_fit.pkl
# 1208 18 520
