# %%
import os
import sys
sys.path.append(os.path.abspath('../'))
from dataset.preload import PreloadDataset
import os.path as path
import logging
from dataset.vocab import *
from arguments import parse_args

args = parse_args()
# Configure logging for better debugging information
logging.basicConfig(level=logging.INFO,  
                    format='%(asctime)s - %(levelname)s - %(message)s')  
log = logging.getLogger(__name__)

# %%
include_user_features = args.include_user_features
include_time_features = args.include_time_features
include_market_features = args.include_market_features
include_exo_features = args.include_exo_features

fextension = ""
if include_user_features:
    fextension += "_user"
if include_market_features:
    fextension += "_market"
if include_time_features:
    fextension += "_time"
if include_exo_features:
    fextension += "_exoLagged"

# %%
# Root and file configurations
#root = "/data/IDEA_DeFi_Research/Data/eCommerce/Cosmetics/preprocessed/"  
root = "/data/IDEA_DeFi_Research/Data/AML/LI_Small/preprocessed/"
fname = f"transactions{fextension}_train"  
val_fname = "" 
test_fname = f"transactions{fextension}_test"  
fextension = ""  # Use empty string instead of False to avoid confusion
vocab_dir = "vocab/"
cached = False
val_cached = False
test_cached = False
vocab_cached = False
encoder_cached = False
external_encoder_path = False  # Initialize as empty string for consistency

# Ensure fextension and external_encoder_path are strings
fextension = fextension if fextension else ""
external_encoder_path = external_encoder_path if external_encoder_path else ""

# Class name of the dataset to be instantiated
dataset_class = "PreloadDataset"

# Instantiate the dataset for preloading
dataset = eval(dataset_class)(
    num_bins=10,
    cached=False,  # Set as False to force reloading for the first run
    encoder_cached=False,
    external_encoder_path=external_encoder_path,
    vocab_cached=False,
    root=root,
    fname=fname,
    vocab_dir=vocab_dir,
    fextension=fextension,
    nrows=None,
    adap_thres=10 ** 8,
    get_rids=True,
    columns_to_select=None
)

# Print out vocab sizes for verification
print(len(dataset.dynamic_vocab), len(dataset.time_feature_vocab), len(dataset.static_vocab))
# Out:
# 2025-02-10 10:13:44,319 - INFO - read data : (6049093, 70)
# 2025-02-10 10:13:44,320 - INFO - /data/IDEA_DeFi_Research/Data/AML/LI_Small/preprocessed/transactions_user_time_train.csv is read.
# 2025-02-10 10:13:44,320 - INFO - nan resolution.
# 2025-02-10 10:13:48,112 - INFO - timestamp fit transform
# 2025-02-10 10:13:48,113 - INFO - label-fit-transform.
#   0%|          | 0/6 [00:00<?, ?it/s]2025-02-10 10:13:48,115 - INFO - skipping col user
# 100%|██████████| 6/6 [00:03<00:00,  1.78it/s]
# 2025-02-10 10:13:51,494 - INFO - amount quant transform
#   0%|          | 0/64 [00:00<?, ?it/s]2025-02-10 10:13:51,496 - INFO - skipping col rowNumber
# 2025-02-10 10:13:51,496 - INFO - skipping col timestamp
# 2025-02-10 10:13:51,497 - INFO - skipping col id
# 2025-02-10 10:13:51,499 - INFO - encoding userBank
#   6%|▋         | 4/64 [00:00<00:01, 36.80it/s]2025-02-10 10:13:51,618 - INFO - encoding recipientBank
# 2025-02-10 10:13:51,831 - INFO - encoding amountReceived
# 2025-02-10 10:13:52,131 - INFO - encoding amount
# 2025-02-10 10:13:52,459 - INFO - encoding timeOfDay
#  12%|█▎        | 8/64 [00:01<00:10,  5.50it/s]2025-02-10 10:13:52,768 - INFO - encoding dayOfWeek
# 2025-02-10 10:13:52,958 - INFO - encoding dayOfMonth
#  16%|█▌        | 10/64 [00:01<00:10,  5.37it/s]2025-02-10 10:13:53,161 - INFO - encoding dayOfYear
# 2025-02-10 10:13:53,362 - INFO - encoding quarter
#  19%|█▉        | 12/64 [00:01<00:09,  5.63it/s]2025-02-10 10:13:53,477 - INFO - encoding dayOfQuarter
#  20%|██        | 13/64 [00:02<00:09,  5.55it/s]2025-02-10 10:13:53,668 - INFO - encoding sinTimeOfDay
#  22%|██▏       | 14/64 [00:02<00:09,  5.20it/s]2025-02-10 10:13:53,909 - INFO - encoding cosTimeOfDay
#  23%|██▎       | 15/64 [00:02<00:09,  4.98it/s]2025-02-10 10:13:54,139 - INFO - encoding sinDayOfWeek
#  25%|██▌       | 16/64 [00:02<00:09,  5.00it/s]2025-02-10 10:13:54,350 - INFO - encoding cosDayOfWeek
#  27%|██▋       | 17/64 [00:03<00:09,  4.98it/s]2025-02-10 10:13:54,554 - INFO - encoding sinDayOfMonth
#  28%|██▊       | 18/64 [00:03<00:09,  4.86it/s]2025-02-10 10:13:54,759 - INFO - encoding cosDayOfMonth
#  30%|██▉       | 19/64 [00:03<00:09,  4.99it/s]2025-02-10 10:13:54,945 - INFO - encoding sinDayOfQuarter
#  31%|███▏      | 20/64 [00:03<00:08,  4.97it/s]2025-02-10 10:13:55,149 - INFO - encoding cosDayOfQuarter
#  33%|███▎      | 21/64 [00:03<00:08,  5.06it/s]2025-02-10 10:13:55,338 - INFO - encoding sinDayOfYear
#  34%|███▍      | 22/64 [00:04<00:08,  5.04it/s]2025-02-10 10:13:55,539 - INFO - encoding cosDayOfYear
#  36%|███▌      | 23/64 [00:04<00:08,  5.10it/s]2025-02-10 10:13:55,728 - INFO - encoding sinQuarter
#  38%|███▊      | 24/64 [00:04<00:07,  5.52it/s]2025-02-10 10:13:55,874 - INFO - encoding cosQuarter
#  39%|███▉      | 25/64 [00:04<00:06,  6.00it/s]2025-02-10 10:13:56,006 - INFO - encoding userSecondsSinceFirstTransaction
#  41%|████      | 26/64 [00:04<00:07,  5.41it/s]2025-02-10 10:13:56,234 - INFO - encoding userSecondsSincePreviousTransaction
#  42%|████▏     | 27/64 [00:05<00:08,  4.61it/s]2025-02-10 10:13:56,526 - INFO - encoding userChequeCount
#  44%|████▍     | 28/64 [00:05<00:07,  4.97it/s]2025-02-10 10:13:56,690 - INFO - encoding userChequeSumAmount
#  45%|████▌     | 29/64 [00:05<00:06,  5.41it/s]2025-02-10 10:13:56,838 - INFO - encoding userChequeAvgAmount
#  47%|████▋     | 30/64 [00:05<00:06,  5.54it/s]2025-02-10 10:13:57,012 - INFO - encoding userChequeSumAmountreceived
#  48%|████▊     | 31/64 [00:05<00:05,  5.82it/s]2025-02-10 10:13:57,163 - INFO - encoding userChequeAvgAmountreceived
#  50%|█████     | 32/64 [00:05<00:05,  5.78it/s]2025-02-10 10:13:57,334 - INFO - encoding userReinvestmentCount
#  52%|█████▏    | 33/64 [00:05<00:04,  6.51it/s]2025-02-10 10:13:57,443 - INFO - encoding userReinvestmentSumAmount
#  53%|█████▎    | 34/64 [00:06<00:04,  6.61it/s]2025-02-10 10:13:57,589 - INFO - encoding userReinvestmentAvgAmount
#  55%|█████▍    | 35/64 [00:06<00:04,  6.81it/s]2025-02-10 10:13:57,725 - INFO - encoding userReinvestmentSumAmountreceived
#  56%|█████▋    | 36/64 [00:06<00:04,  6.79it/s]2025-02-10 10:13:57,874 - INFO - encoding userReinvestmentAvgAmountreceived
#  58%|█████▊    | 37/64 [00:06<00:03,  6.92it/s]2025-02-10 10:13:58,011 - INFO - encoding userCredit cardCount
#  59%|█████▉    | 38/64 [00:06<00:03,  6.67it/s]2025-02-10 10:13:58,187 - INFO - encoding userCredit cardSumAmount
#  61%|██████    | 39/64 [00:06<00:03,  6.66it/s]2025-02-10 10:13:58,339 - INFO - encoding userCredit cardAvgAmount
#  62%|██████▎   | 40/64 [00:06<00:03,  6.40it/s]2025-02-10 10:13:58,495 - INFO - encoding userCredit cardSumAmountreceived
#  64%|██████▍   | 41/64 [00:07<00:03,  6.64it/s]2025-02-10 10:13:58,633 - INFO - encoding userCredit cardAvgAmountreceived
#  66%|██████▌   | 42/64 [00:07<00:03,  6.58it/s]2025-02-10 10:13:58,788 - INFO - encoding userAchCount
#  67%|██████▋   | 43/64 [00:07<00:02,  7.32it/s]2025-02-10 10:13:58,889 - INFO - encoding userAchSumAmount
#  69%|██████▉   | 44/64 [00:07<00:02,  7.66it/s]2025-02-10 10:13:59,005 - INFO - encoding userAchAvgAmount
#  70%|███████   | 45/64 [00:07<00:02,  8.18it/s]2025-02-10 10:13:59,108 - INFO - encoding userAchSumAmountreceived
#  72%|███████▏  | 46/64 [00:07<00:02,  8.33it/s]2025-02-10 10:13:59,223 - INFO - encoding userAchAvgAmountreceived
#  73%|███████▎  | 47/64 [00:07<00:01,  8.69it/s]2025-02-10 10:13:59,327 - INFO - encoding userCashCount
#  75%|███████▌  | 48/64 [00:07<00:01,  8.81it/s]2025-02-10 10:13:59,436 - INFO - encoding userCashSumAmount
# 2025-02-10 10:13:59,527 - INFO - encoding userCashAvgAmount
#  78%|███████▊  | 50/64 [00:08<00:01,  9.38it/s]2025-02-10 10:13:59,633 - INFO - encoding userCashSumAmountreceived
# 2025-02-10 10:13:59,724 - INFO - encoding userCashAvgAmountreceived
#  81%|████████▏ | 52/64 [00:08<00:01,  9.66it/s]2025-02-10 10:13:59,835 - INFO - encoding userWireCount
# 2025-02-10 10:13:59,897 - INFO - encoding userWireSumAmount
#  84%|████████▍ | 54/64 [00:08<00:00, 10.93it/s]2025-02-10 10:13:59,972 - INFO - encoding userWireAvgAmount
# 2025-02-10 10:14:00,031 - INFO - encoding userWireSumAmountreceived
#  88%|████████▊ | 56/64 [00:08<00:00, 12.01it/s]2025-02-10 10:14:00,106 - INFO - encoding userWireAvgAmountreceived
# 2025-02-10 10:14:00,165 - INFO - encoding userBitcoinCount
#  91%|█████████ | 58/64 [00:08<00:00, 13.71it/s]2025-02-10 10:14:00,210 - INFO - encoding userBitcoinSumAmount
# 2025-02-10 10:14:00,242 - INFO - encoding userBitcoinAvgAmount
# 2025-02-10 10:14:00,298 - INFO - encoding userBitcoinSumAmountreceived
#  95%|█████████▌| 61/64 [00:08<00:00, 16.88it/s]2025-02-10 10:14:00,341 - INFO - encoding userBitcoinAvgAmountreceived
# 2025-02-10 10:14:00,383 - INFO - encoding timeFeature
#  98%|█████████▊| 63/64 [00:09<00:00, 13.05it/s]2025-02-10 10:14:00,571 - INFO - encoding Year
# 100%|██████████| 64/64 [00:09<00:00,  6.97it/s]
# 2025-02-10 10:14:01,559 - INFO - writing cached csv to /data/IDEA_DeFi_Research/Data/AML/LI_Small/preprocessed/preprocessed/transactions_user_time_train.encoded.csv
# 2025-02-10 10:14:01,562 - INFO - writing to file /data/IDEA_DeFi_Research/Data/AML/LI_Small/preprocessed/preprocessed/transactions_user_time_train.encoded.csv
# 2025-02-10 10:15:03,823 - INFO - writing cached encoder fit to /data/IDEA_DeFi_Research/Data/AML/LI_Small/preprocessed/preprocessed/transactions_user_time_train.encoder_fit.pkl
# 2025-02-10 10:15:03,878 - INFO - starting with 70 columns
# 2025-02-10 10:15:05,269 - INFO - total columns: ['rowNumber', 'user', 'timestamp', 'id', 'timeOfDay', 'type', 'cosQuarter', 'cosDayOfYear', 'dayOfMonth', 'amountReceived', 'cosDayOfQuarter', 'amount', 'recipientBank', 'dayOfYear', 'sinDayOfQuarter', 'cosTimeOfDay', 'sinTimeOfDay', 'dayOfQuarter', 'cosDayOfMonth', 'reserve', 'Receiving Currency', 'dayOfWeek', 'sinDayOfWeek', 'sinDayOfMonth', 'quarter', 'cosDayOfWeek', 'sinQuarter', 'sinDayOfYear', 'isWeekend', 'Year', 'timeFeature', 'userBitcoinSumAmount', 'userChequeAvgAmountreceived', 'userCredit cardSumAmountreceived', 'userCashCount', 'userBitcoinCount', 'userSecondsSinceFirstTransaction', 'userCashAvgAmountreceived', 'userBitcoinAvgAmountreceived', 'userReinvestmentSumAmountreceived', 'userChequeSumAmount', 'userReinvestmentAvgAmount', 'userCredit cardAvgAmount', 'userCredit cardCount', 'userAchAvgAmount', 'userAchAvgAmountreceived', 'userChequeSumAmountreceived', 'userBitcoinSumAmountreceived', 'userCashAvgAmount', 'userBitcoinAvgAmount', 'userReinvestmentSumAmount', 'userCashSumAmountreceived', 'userAchCount', 'userWireSumAmount', 'userWireSumAmountreceived', 'userSecondsSincePreviousTransaction', 'userAchSumAmount', 'userReinvestmentCount', 'userWireCount', 'userChequeAvgAmount', 'userIsNew', 'userWireAvgAmount', 'userChequeCount', 'userReinvestmentAvgAmountreceived', 'userWireAvgAmountreceived', 'userCashSumAmount', 'userBank', 'userAchSumAmountreceived', 'userCredit cardAvgAmountreceived', 'userCredit cardSumAmount'], total dynamic columns: ['timeOfDay', 'type', 'cosQuarter', 'cosDayOfYear', 'dayOfMonth', 'amountReceived', 'cosDayOfQuarter', 'amount', 'recipientBank', 'dayOfYear', 'sinDayOfQuarter', 'cosTimeOfDay', 'sinTimeOfDay', 'dayOfQuarter', 'cosDayOfMonth', 'reserve', 'Receiving Currency', 'dayOfWeek', 'sinDayOfWeek', 'sinDayOfMonth', 'quarter', 'cosDayOfWeek', 'sinQuarter', 'sinDayOfYear', 'isWeekend', 'Year'], total time feature columns: ['timeFeature'],total static columns: ['userBitcoinSumAmount', 'userChequeAvgAmountreceived', 'userCredit cardSumAmountreceived', 'userCashCount', 'userBitcoinCount', 'userSecondsSinceFirstTransaction', 'userCashAvgAmountreceived', 'userBitcoinAvgAmountreceived', 'userReinvestmentSumAmountreceived', 'userChequeSumAmount', 'userReinvestmentAvgAmount', 'userCredit cardAvgAmount', 'userCredit cardCount', 'userAchAvgAmount', 'userAchAvgAmountreceived', 'userChequeSumAmountreceived', 'userBitcoinSumAmountreceived', 'userCashAvgAmount', 'userBitcoinAvgAmount', 'userReinvestmentSumAmount', 'userCashSumAmountreceived', 'userAchCount', 'userWireSumAmount', 'userWireSumAmountreceived', 'userSecondsSincePreviousTransaction', 'userAchSumAmount', 'userReinvestmentCount', 'userWireCount', 'userChequeAvgAmount', 'userIsNew', 'userWireAvgAmount', 'userChequeCount', 'userReinvestmentAvgAmountreceived', 'userWireAvgAmountreceived', 'userCashSumAmount', 'userBank', 'userAchSumAmountreceived', 'userCredit cardAvgAmountreceived', 'userCredit cardSumAmount']
# 2025-02-10 10:15:05,270 - INFO - total dynamic vocabulary size: 218, total time feature vocabulary size: 18, total static vocabulary size: 416
# 2025-02-10 10:15:05,270 - INFO - column : timeOfDay, vocab size : 11
# 2025-02-10 10:15:05,271 - INFO - column : type, vocab size : 8
# 2025-02-10 10:15:05,271 - INFO - column : cosQuarter, vocab size : 2
# 2025-02-10 10:15:05,271 - INFO - column : cosDayOfYear, vocab size : 8
# 2025-02-10 10:15:05,272 - INFO - column : dayOfMonth, vocab size : 8
# 2025-02-10 10:15:05,273 - INFO - column : amountReceived, vocab size : 11
# 2025-02-10 10:15:05,273 - INFO - column : cosDayOfQuarter, vocab size : 8
# 2025-02-10 10:15:05,274 - INFO - column : amount, vocab size : 11
# 2025-02-10 10:15:05,274 - INFO - column : recipientBank, vocab size : 11
# 2025-02-10 10:15:05,274 - INFO - column : dayOfYear, vocab size : 8
# 2025-02-10 10:15:05,275 - INFO - column : sinDayOfQuarter, vocab size : 9
# 2025-02-10 10:15:05,275 - INFO - column : cosTimeOfDay, vocab size : 11
# 2025-02-10 10:15:05,276 - INFO - column : sinTimeOfDay, vocab size : 11
# 2025-02-10 10:15:05,276 - INFO - column : dayOfQuarter, vocab size : 8
# 2025-02-10 10:15:05,277 - INFO - column : cosDayOfMonth, vocab size : 9
# 2025-02-10 10:15:05,278 - INFO - column : reserve, vocab size : 16
# 2025-02-10 10:15:05,278 - INFO - column : Receiving Currency, vocab size : 16
# 2025-02-10 10:15:05,278 - INFO - column : dayOfWeek, vocab size : 6
# 2025-02-10 10:15:05,279 - INFO - column : sinDayOfWeek, vocab size : 6
# 2025-02-10 10:15:05,279 - INFO - column : sinDayOfMonth, vocab size : 8
# 2025-02-10 10:15:05,279 - INFO - column : quarter, vocab size : 2
# 2025-02-10 10:15:05,280 - INFO - column : cosDayOfWeek, vocab size : 7
# 2025-02-10 10:15:05,280 - INFO - column : sinQuarter, vocab size : 2
# 2025-02-10 10:15:05,281 - INFO - column : sinDayOfYear, vocab size : 9
# 2025-02-10 10:15:05,281 - INFO - column : isWeekend, vocab size : 3
# 2025-02-10 10:15:05,281 - INFO - column : Year, vocab size : 2
# 2025-02-10 10:15:05,282 - INFO - column : SPECIAL, vocab size : 7
# 2025-02-10 10:15:05,283 - INFO - column : timeFeature, vocab size : 11
# 2025-02-10 10:15:05,283 - INFO - column : SPECIAL, vocab size : 7
# 2025-02-10 10:15:05,284 - INFO - column : userBitcoinSumAmount, vocab size : 11
# 2025-02-10 10:15:05,284 - INFO - column : userChequeAvgAmountreceived, vocab size : 11
# 2025-02-10 10:15:05,285 - INFO - column : userCredit cardSumAmountreceived, vocab size : 11
# 2025-02-10 10:15:05,285 - INFO - column : userCashCount, vocab size : 10
# 2025-02-10 10:15:05,286 - INFO - column : userBitcoinCount, vocab size : 11
# 2025-02-10 10:15:05,286 - INFO - column : userSecondsSinceFirstTransaction, vocab size : 11
# 2025-02-10 10:15:05,286 - INFO - column : userCashAvgAmountreceived, vocab size : 11
# 2025-02-10 10:15:05,287 - INFO - column : userBitcoinAvgAmountreceived, vocab size : 11
# 2025-02-10 10:15:05,287 - INFO - column : userReinvestmentSumAmountreceived, vocab size : 11
# 2025-02-10 10:15:05,288 - INFO - column : userChequeSumAmount, vocab size : 11
# 2025-02-10 10:15:05,288 - INFO - column : userReinvestmentAvgAmount, vocab size : 11
# 2025-02-10 10:15:05,288 - INFO - column : userCredit cardAvgAmount, vocab size : 11
# 2025-02-10 10:15:05,289 - INFO - column : userCredit cardCount, vocab size : 11
# 2025-02-10 10:15:05,289 - INFO - column : userAchAvgAmount, vocab size : 11
# 2025-02-10 10:15:05,289 - INFO - column : userAchAvgAmountreceived, vocab size : 11
# 2025-02-10 10:15:05,290 - INFO - column : userChequeSumAmountreceived, vocab size : 11
# 2025-02-10 10:15:05,290 - INFO - column : userBitcoinSumAmountreceived, vocab size : 11
# 2025-02-10 10:15:05,291 - INFO - column : userCashAvgAmount, vocab size : 11
# 2025-02-10 10:15:05,291 - INFO - column : userBitcoinAvgAmount, vocab size : 11
# 2025-02-10 10:15:05,292 - INFO - column : userReinvestmentSumAmount, vocab size : 11
# 2025-02-10 10:15:05,292 - INFO - column : userCashSumAmountreceived, vocab size : 11
# 2025-02-10 10:15:05,292 - INFO - column : userAchCount, vocab size : 9
# 2025-02-10 10:15:05,294 - INFO - column : userWireSumAmount, vocab size : 11
# 2025-02-10 10:15:05,295 - INFO - column : userWireSumAmountreceived, vocab size : 11
# 2025-02-10 10:15:05,295 - INFO - column : userSecondsSincePreviousTransaction, vocab size : 11
# 2025-02-10 10:15:05,295 - INFO - column : userAchSumAmount, vocab size : 11
# 2025-02-10 10:15:05,296 - INFO - column : userReinvestmentCount, vocab size : 4
# 2025-02-10 10:15:05,296 - INFO - column : userWireCount, vocab size : 9
# 2025-02-10 10:15:05,297 - INFO - column : userChequeAvgAmount, vocab size : 11
# 2025-02-10 10:15:05,297 - INFO - column : userIsNew, vocab size : 3
# 2025-02-10 10:15:05,297 - INFO - column : userWireAvgAmount, vocab size : 11
# 2025-02-10 10:15:05,298 - INFO - column : userChequeCount, vocab size : 11
# 2025-02-10 10:15:05,298 - INFO - column : userReinvestmentAvgAmountreceived, vocab size : 11
# 2025-02-10 10:15:05,299 - INFO - column : userWireAvgAmountreceived, vocab size : 11
# 2025-02-10 10:15:05,299 - INFO - column : userCashSumAmount, vocab size : 11
# 2025-02-10 10:15:05,299 - INFO - column : userBank, vocab size : 11
# 2025-02-10 10:15:05,300 - INFO - column : userAchSumAmountreceived, vocab size : 11
# 2025-02-10 10:15:05,300 - INFO - column : userCredit cardAvgAmountreceived, vocab size : 11
# 2025-02-10 10:15:05,300 - INFO - column : userCredit cardSumAmount, vocab size : 11
# 2025-02-10 10:15:05,301 - INFO - column : SPECIAL, vocab size : 7
# 2025-02-10 10:15:05,301 - INFO - saving vocab at /data/IDEA_DeFi_Research/Data/AML/LI_Small/preprocessed//vocab/dynamic_vocab.nb
# 2025-02-10 10:15:05,320 - INFO - saving vocab object at /data/IDEA_DeFi_Research/Data/AML/LI_Small/preprocessed//vocab/dynamic_vocab_ob
# 2025-02-10 10:15:05,321 - INFO - saving vocab at /data/IDEA_DeFi_Research/Data/AML/LI_Small/preprocessed//vocab/time_feature_vocab.nb
# 2025-02-10 10:15:05,335 - INFO - saving vocab object at /data/IDEA_DeFi_Research/Data/AML/LI_Small/preprocessed//vocab/time_feature_vocab_ob
# 2025-02-10 10:15:05,335 - INFO - saving vocab at /data/IDEA_DeFi_Research/Data/AML/LI_Small/preprocessed//vocab/static_vocab.nb
# 2025-02-10 10:15:05,347 - INFO - saving vocab object at /data/IDEA_DeFi_Research/Data/AML/LI_Small/preprocessed//vocab/static_vocab_ob
# 218 18 416

# %%
# If the encoder wasn't cached before, set the external path to the newly generated encoder
if not encoder_cached:
    print(f"dataset.encoder_path: {dataset.encoder_path}")
    external_encoder_path = dataset.encoder_path
    
# Update flags indicating caching is now done
vocab_cached = True
encoder_cached = True

test_dataset = eval(dataset_class)(
    num_bins=10,
    cached=False,  # Disable cached to generate fresh encoded data
    encoder_cached=encoder_cached,  # Force generation of a new encoder if missing
    external_encoder_path=external_encoder_path,  # Should be empty or point to existing encoder
    vocab_cached=vocab_cached,
    root=root,
    fname=test_fname,
    vocab_dir=vocab_dir,
    fextension=fextension,
    nrows=None,
    adap_thres=10 ** 8,
    get_rids=True,
    columns_to_select=None
)

# Print out vocab sizes for the test dataset to ensure consistency
print(len(test_dataset.dynamic_vocab), len(test_dataset.time_feature_vocab), len(test_dataset.static_vocab))
# Out:
# 2025-02-10 10:15:05,353 - INFO - cached encoder is read from /data/IDEA_DeFi_Research/Data/AML/LI_Small/preprocessed/preprocessed/transactions_user_time_train.encoder_fit.pkl
# dataset.encoder_path: /data/IDEA_DeFi_Research/Data/AML/LI_Small/preprocessed/preprocessed/transactions_user_time_train.encoder_fit.pkl
# 2025-02-10 10:15:34,179 - INFO - read data : (2269478, 70)
# 2025-02-10 10:15:34,180 - INFO - /data/IDEA_DeFi_Research/Data/AML/LI_Small/preprocessed/transactions_user_time_test.csv is read.
# 2025-02-10 10:15:34,180 - INFO - nan resolution.
# 2025-02-10 10:15:35,613 - INFO - timestamp fit transform
# 2025-02-10 10:15:35,614 - INFO - label-fit-transform.
#   0%|          | 0/6 [00:00<?, ?it/s]2025-02-10 10:15:35,615 - INFO - skipping col user
# 100%|██████████| 6/6 [00:01<00:00,  5.15it/s]
# 2025-02-10 10:15:36,780 - INFO - amount quant transform
#   0%|          | 0/64 [00:00<?, ?it/s]2025-02-10 10:15:36,782 - INFO - skipping col rowNumber
# 2025-02-10 10:15:36,782 - INFO - skipping col timestamp
# 2025-02-10 10:15:36,783 - INFO - skipping col id
# 2025-02-10 10:15:36,785 - INFO - encoding userBank
# 2025-02-10 10:15:36,809 - INFO - encoding recipientBank
# 2025-02-10 10:15:36,844 - INFO - encoding amountReceived
#   9%|▉         | 6/64 [00:00<00:01, 56.14it/s]2025-02-10 10:15:36,891 - INFO - encoding amount
# 2025-02-10 10:15:36,936 - INFO - encoding timeOfDay
# 2025-02-10 10:15:36,979 - INFO - encoding dayOfWeek
# 2025-02-10 10:15:37,004 - INFO - encoding dayOfMonth
# 2025-02-10 10:15:37,027 - INFO - encoding dayOfYear
# 2025-02-10 10:15:37,050 - INFO - encoding quarter
#  19%|█▉        | 12/64 [00:00<00:01, 40.57it/s]2025-02-10 10:15:37,068 - INFO - encoding dayOfQuarter
# 2025-02-10 10:15:37,091 - INFO - encoding sinTimeOfDay
# 2025-02-10 10:15:37,136 - INFO - encoding cosTimeOfDay
# 2025-02-10 10:15:37,182 - INFO - encoding sinDayOfWeek
# 2025-02-10 10:15:37,208 - INFO - encoding cosDayOfWeek
#  27%|██▋       | 17/64 [00:00<00:01, 35.49it/s]2025-02-10 10:15:37,233 - INFO - encoding sinDayOfMonth
# 2025-02-10 10:15:37,258 - INFO - encoding cosDayOfMonth
# 2025-02-10 10:15:37,285 - INFO - encoding sinDayOfQuarter
# 2025-02-10 10:15:37,311 - INFO - encoding cosDayOfQuarter
#  33%|███▎      | 21/64 [00:00<00:01, 36.65it/s]2025-02-10 10:15:37,335 - INFO - encoding sinDayOfYear
# 2025-02-10 10:15:37,362 - INFO - encoding cosDayOfYear
# 2025-02-10 10:15:37,386 - INFO - encoding sinQuarter
# 2025-02-10 10:15:37,401 - INFO - encoding cosQuarter
# 2025-02-10 10:15:37,417 - INFO - encoding userSecondsSinceFirstTransaction
#  41%|████      | 26/64 [00:00<00:00, 39.05it/s]2025-02-10 10:15:37,448 - INFO - encoding userSecondsSincePreviousTransaction
# 2025-02-10 10:15:37,501 - INFO - encoding userChequeCount
# 2025-02-10 10:15:37,526 - INFO - encoding userChequeSumAmount
# 2025-02-10 10:15:37,551 - INFO - encoding userChequeAvgAmount
# 2025-02-10 10:15:37,580 - INFO - encoding userChequeSumAmountreceived
#  48%|████▊     | 31/64 [00:00<00:00, 36.21it/s]2025-02-10 10:15:37,605 - INFO - encoding userChequeAvgAmountreceived
# 2025-02-10 10:15:37,635 - INFO - encoding userReinvestmentCount
# 2025-02-10 10:15:37,652 - INFO - encoding userReinvestmentSumAmount
# 2025-02-10 10:15:37,673 - INFO - encoding userReinvestmentAvgAmount
# 2025-02-10 10:15:37,694 - INFO - encoding userReinvestmentSumAmountreceived
#  56%|█████▋    | 36/64 [00:00<00:00, 38.81it/s]2025-02-10 10:15:37,716 - INFO - encoding userReinvestmentAvgAmountreceived
# 2025-02-10 10:15:37,736 - INFO - encoding userCredit cardCount
# 2025-02-10 10:15:37,760 - INFO - encoding userCredit cardSumAmount
# 2025-02-10 10:15:37,785 - INFO - encoding userCredit cardAvgAmount
# 2025-02-10 10:15:37,811 - INFO - encoding userCredit cardSumAmountreceived
#  64%|██████▍   | 41/64 [00:01<00:00, 39.77it/s]2025-02-10 10:15:37,835 - INFO - encoding userCredit cardAvgAmountreceived
# 2025-02-10 10:15:37,861 - INFO - encoding userAchCount
# 2025-02-10 10:15:37,881 - INFO - encoding userAchSumAmount
# 2025-02-10 10:15:37,901 - INFO - encoding userAchAvgAmount
# 2025-02-10 10:15:37,922 - INFO - encoding userAchSumAmountreceived
#  72%|███████▏  | 46/64 [00:01<00:00, 41.61it/s]2025-02-10 10:15:37,943 - INFO - encoding userAchAvgAmountreceived
# 2025-02-10 10:15:37,963 - INFO - encoding userCashCount
# 2025-02-10 10:15:37,981 - INFO - encoding userCashSumAmount
# 2025-02-10 10:15:37,998 - INFO - encoding userCashAvgAmount
# 2025-02-10 10:15:38,016 - INFO - encoding userCashSumAmountreceived
# 2025-02-10 10:15:38,033 - INFO - encoding userCashAvgAmountreceived
#  81%|████████▏ | 52/64 [00:01<00:00, 45.47it/s]2025-02-10 10:15:38,052 - INFO - encoding userWireCount
# 2025-02-10 10:15:38,065 - INFO - encoding userWireSumAmount
# 2025-02-10 10:15:38,078 - INFO - encoding userWireAvgAmount
# 2025-02-10 10:15:38,092 - INFO - encoding userWireSumAmountreceived
# 2025-02-10 10:15:38,105 - INFO - encoding userWireAvgAmountreceived
# 2025-02-10 10:15:38,119 - INFO - encoding userBitcoinCount
# 2025-02-10 10:15:38,127 - INFO - encoding userBitcoinSumAmount
# 2025-02-10 10:15:38,136 - INFO - encoding userBitcoinAvgAmount
# 2025-02-10 10:15:38,144 - INFO - encoding userBitcoinSumAmountreceived
#  95%|█████████▌| 61/64 [00:01<00:00, 57.52it/s]2025-02-10 10:15:38,153 - INFO - encoding userBitcoinAvgAmountreceived
# 2025-02-10 10:15:38,161 - INFO - encoding timeFeature
# 2025-02-10 10:15:38,189 - INFO - encoding Year
# 100%|██████████| 64/64 [00:01<00:00, 45.02it/s]
# 2025-02-10 10:15:38,543 - INFO - writing cached csv to /data/IDEA_DeFi_Research/Data/AML/LI_Small/preprocessed/preprocessed/transactions_user_time_test.encoded.csv
# 2025-02-10 10:15:38,544 - INFO - writing to file /data/IDEA_DeFi_Research/Data/AML/LI_Small/preprocessed/preprocessed/transactions_user_time_test.encoded.csv
# 2025-02-10 10:16:02,131 - INFO - writing cached encoder fit to /data/IDEA_DeFi_Research/Data/AML/LI_Small/preprocessed/preprocessed/transactions_user_time_test.encoder_fit.pkl
# 218 18 416
