# %%
import pandas as pd
import pyreadr

# %%
# Load survival data
indexEvent = "Withdraw/"
outcomeEvent = "Borrow/"
file_path = f"/data/IDEA_DeFi_Research/Data/Survival_Data_F24/{indexEvent}{outcomeEvent}y_train.rds"
result = pyreadr.read_r(file_path)
survivalData = result[None]
print(survivalData.head())
# Out:
#      timeDiff  status                                                 id  \
# 0  49810455.0     0.0  0x0c66ade8a26d0bedbc967005a75a00028cebf222ec45...
# 1  49807265.0     0.0  0x25f636e7b49a599c765bcdac00853265ac76a5921953...
# 2  49806318.0     0.0  0x17869b1999e221cb74ab4fc8c9f7087097e6e27b50dd...
# 3  49734675.0     0.0  0xae1083a26ffc90a681fc856b9bb087e37a16c037227a...
# 4  49730289.0     0.0  0xd12cbbad05aa4b7dbcf62ee862bf07c73ddfca58f035...
#
#   Index Event Outcome Event
# 0    withdraw        borrow
# 1    withdraw        borrow
# 2    withdraw        borrow
# 3    withdraw        borrow
# 4    withdraw        borrow

# %%
survivalData = survivalData[['id', 'timeDiff', 'status']]
survivalData_test = survivalData[:10]

# %%
# Load raw transaction data
file_path = 'data/transactionsAave.csv'
rawData = pd.read_csv(file_path, low_memory=False)  
sort_columns =  ['user', 'timestamp']
rawData = rawData.sort_values(by=sort_columns)

# %%
print(rawData.head())
# Out:
#                                                        id        type  \
# 482454  0x3fec3516c8085e089d408562dd3f9ca1bbbc5b0eb4ea...  collateral
# 658731  0x452f5f9b8d503f395a1db08a2bd8f3af937d401d5358...  collateral
# 317991  0x59a33c72e045d762a069ddfe10540ddc1b521cbd27e1...  collateral
# 473278  0x3c07de24894604a8e9fd36be5eda98a8f9fdad794536...  collateral
# 655032  0x090c9fb05186afb08a0e311160409f24b5aa33de8ea1...  collateral
#
#            timestamp                                        user  \
# 482454  1.626954e+09  0x0000000000000000000000000000000000000001
# 658731  1.657433e+09  0x0000000000000000000000000000000000000001
# 317991  1.613978e+09  0x000000000000000000000000000000000000dead
# 473278  1.626148e+09  0x000000000000000000000000000000000000dead
# 655032  1.656773e+09  0x000000000000000000000000000000000000dead
#
#                  userAlias onBehalfOf onBehalfOfAlias  \
# 482454  Hamaama al-Shaheed        NaN             NaN
# 658731  Hamaama al-Shaheed        NaN             NaN
# 317991   Shantalle Almanza        NaN             NaN
# 473278   Shantalle Almanza        NaN             NaN
# 655032   Shantalle Almanza        NaN             NaN
#
#                                               pool reserve  amount  ...  \
# 482454  0xb53c1a33016b2dc2ff3653530bff1848a515c8c5     DAI     NaN  ...
# 658731  0xb53c1a33016b2dc2ff3653530bff1848a515c8c5   STETH     NaN  ...
# 317991  0xb53c1a33016b2dc2ff3653530bff1848a515c8c5    WETH     NaN  ...
# 473278  0xb53c1a33016b2dc2ff3653530bff1848a515c8c5    USDT     NaN  ...
# 655032  0xb53c1a33016b2dc2ff3653530bff1848a515c8c5   STETH     NaN  ...
#
#         liquidatorAlias  priceInUsd  borrowRateModeTo borrowRateModeFrom  \
# 482454              NaN         NaN               NaN                NaN
# 658731              NaN         NaN               NaN                NaN
# 317991              NaN         NaN               NaN                NaN
# 473278              NaN         NaN               NaN                NaN
# 655032              NaN         NaN               NaN                NaN
#
#        stableBorrowRate variableBorrowRate target  totalFee version  \
# 482454              NaN                NaN    NaN       NaN      V2
# 658731              NaN                NaN    NaN       NaN      V2
# 317991              NaN                NaN    NaN       NaN      V2
# 473278              NaN                NaN    NaN       NaN      V2
# 655032              NaN                NaN    NaN       NaN      V2
#
#         deployment
# 482454     Mainnet
# 658731     Mainnet
# 317991     Mainnet
# 473278     Mainnet
# 655032     Mainnet
#
# [5 rows x 35 columns]

# %%
samples = []

# Iterate through survival data and extract static and dynamic features
for _, row in survivalData_test.iterrows():
    index_id = row['id']
    index_status = row['status']
    
    # Find the corresponding user for the index event
    user_selection = rawData[rawData['id'] == index_id]['user']
    index_time_selection = rawData[rawData['id'] == index_id]['timestamp']
    if not user_selection.empty and not index_time_selection.empty:
        user = user_selection.iloc[0]
        index_time = index_time_selection.iloc[0]
        
        # Filter transactions for the user before the index time
        user_transactions = rawData[(rawData['user'] == user) & (rawData['timestamp'] <index_time)]
        user_transactions = user_transactions.sort_values(by='timestamp', ascending=False)
        
        # Get the top 5 recent transactions as dynamic features
        dynamic_transactions = user_transactions.head(5)
        
        # Get the remaining transactions as static features
        oldest_dynamic_time = dynamic_transactions['timestamp'].min() if not dynamic_transactions.empty else index_time
        static_transactions = user_transactions[user_transactions['timestamp'] < oldest_dynamic_time]
        
        # Append the sample to the list
        sample = {
            'indexID': index_id,
            'indexTime': index_time,
            'indexStatus': index_status,
            'static_transactions': static_transactions,  # Static feature: transactions before the sliding window
            'dynamic_transactions': dynamic_transactions  # Dynamic feature: last 5 transactions before index event
        }
        samples.append(sample)
    else:
        print(f"No matching user found for indexID: {index_id}")

# %%
# Example output of static and dynamic features
for sample in samples:
    print("IndexID:", sample['indexID'])
    print("Static Transactions:")
    print(sample['static_transactions'])
    print("Dynamic Transactions:")
    print(sample['dynamic_transactions'])
    print("----------------------------------------")
# Out:
# IndexID: 0x0c66ade8a26d0bedbc967005a75a00028cebf222ec45e2b90080e222ed489dcd
# Static Transactions:
# Empty DataFrame
# Columns: [id, type, timestamp, user, userAlias, onBehalfOf, onBehalfOfAlias, pool, reserve, amount, amountUSD, amountETH, borrowRate, borrowRateMode, fromState, toState, liquidator, principalAmount, principalReserve, principalAmountUSD, principalAmountETH, collateralAmount, collateralReserve, collateralAmountUSD, collateralAmountETH, liquidatorAlias, priceInUsd, borrowRateModeTo, borrowRateModeFrom, stableBorrowRate, variableBorrowRate, target, totalFee, version, deployment]
# Index: []
#
# [0 rows x 35 columns]
# Dynamic Transactions:
#                                                        id        type  \
# 259888  0xdd1d259637c499ff61b0d142e7bb6639f3552b2dab37...  collateral
# 893992  0xdd1d259637c499ff61b0d142e7bb6639f3552b2dab37...     deposit
# 259887  0x7f10004def891a9965e972e57ecb8b93c517b5d4d7e4...  collateral
# 893991  0x7f10004def891a9965e972e57ecb8b93c517b5d4d7e4...     deposit
#
#            timestamp                                        user  \
# 259888  1.606837e+09  0xdad4c11e8cc6a5c37808d3b31b3b284809f702d1
# 893992  1.606837e+09  0xdad4c11e8cc6a5c37808d3b31b3b284809f702d1
# 259887  1.606837e+09  0xdad4c11e8cc6a5c37808d3b31b3b284809f702d1
# 893991  1.606837e+09  0xdad4c11e8cc6a5c37808d3b31b3b284809f702d1
#
#              userAlias                                  onBehalfOf  \
# 259888  Jihaad el-Taha                                         NaN
# 893992  Jihaad el-Taha  0xdcd33426ba191383f1c9b431a342498fdac73488
# 259887  Jihaad el-Taha                                         NaN
# 893991  Jihaad el-Taha  0xdad4c11e8cc6a5c37808d3b31b3b284809f702d1
#
#         onBehalfOfAlias                                        pool reserve  \
# 259888              NaN  0xb53c1a33016b2dc2ff3653530bff1848a515c8c5    WETH
# 893992  Tracie Friedman  0xb53c1a33016b2dc2ff3653530bff1848a515c8c5    WETH
# 259887              NaN  0xb53c1a33016b2dc2ff3653530bff1848a515c8c5    AAVE
# 893991   Jihaad el-Taha  0xb53c1a33016b2dc2ff3653530bff1848a515c8c5    AAVE
#
#         amount  ...  liquidatorAlias  priceInUsd  borrowRateModeTo  \
# 259888     NaN  ...              NaN         NaN               NaN
# 893992   0.001  ...              NaN         NaN               NaN
# 259887     NaN  ...              NaN         NaN               NaN
# 893991   0.100  ...              NaN         NaN               NaN
#
#        borrowRateModeFrom stableBorrowRate variableBorrowRate target  \
# 259888                NaN              NaN                NaN    NaN
# 893992                NaN              NaN                NaN    NaN
# 259887                NaN              NaN                NaN    NaN
# 893991                NaN              NaN                NaN    NaN
#
#         totalFee version  deployment
# 259888       NaN      V2     Mainnet
# 893992       NaN      V2     Mainnet
# 259887       NaN      V2     Mainnet
# 893991       NaN      V2     Mainnet
#
# [4 rows x 35 columns]
# ----------------------------------------
# IndexID: 0x25f636e7b49a599c765bcdac00853265ac76a592195346e45126ad00f2ddbca9
# Static Transactions:
# Empty DataFrame
# Columns: [id, type, timestamp, user, userAlias, onBehalfOf, onBehalfOfAlias, pool, reserve, amount, amountUSD, amountETH, borrowRate, borrowRateMode, fromState, toState, liquidator, principalAmount, principalReserve, principalAmountUSD, principalAmountETH, collateralAmount, collateralReserve, collateralAmountUSD, collateralAmountETH, liquidatorAlias, priceInUsd, borrowRateModeTo, borrowRateModeFrom, stableBorrowRate, variableBorrowRate, target, totalFee, version, deployment]
# Index: []
#
# [0 rows x 35 columns]
# Dynamic Transactions:
#                                                        id        type  \
# 259892  0x870bf17a6373c10290d626134936230ada5f8ab0eee2...  collateral
# 893993  0x870bf17a6373c10290d626134936230ada5f8ab0eee2...     deposit
#
#            timestamp                                        user  \
# 259892  1.606840e+09  0xbd723fc4f1d737dcfc48a07fe7336766d34cad5f
# 893993  1.606840e+09  0xbd723fc4f1d737dcfc48a07fe7336766d34cad5f
#
#               userAlias                                  onBehalfOf  \
# 259892  Brooklyn Dingle                                         NaN
# 893993  Brooklyn Dingle  0xdcd33426ba191383f1c9b431a342498fdac73488
#
#         onBehalfOfAlias                                        pool reserve  \
# 259892              NaN  0xb53c1a33016b2dc2ff3653530bff1848a515c8c5    WETH
# 893993  Tracie Friedman  0xb53c1a33016b2dc2ff3653530bff1848a515c8c5    WETH
#
#         amount  ...  liquidatorAlias  priceInUsd  borrowRateModeTo  \
# 259892     NaN  ...              NaN         NaN               NaN
# 893993   0.001  ...              NaN         NaN               NaN
#
#        borrowRateModeFrom stableBorrowRate variableBorrowRate target  \
# 259892                NaN              NaN                NaN    NaN
# 893993                NaN              NaN                NaN    NaN
#
#         totalFee version  deployment
# 259892       NaN      V2     Mainnet
# 893993       NaN      V2     Mainnet
#
# [2 rows x 35 columns]
# ----------------------------------------
# IndexID: 0x17869b1999e221cb74ab4fc8c9f7087097e6e27b50ddbeb5177ce3e3de8352d2
# Static Transactions:
#                                                        id        type  \
# 259892  0x870bf17a6373c10290d626134936230ada5f8ab0eee2...  collateral
# 893993  0x870bf17a6373c10290d626134936230ada5f8ab0eee2...     deposit
#
#            timestamp                                        user  \
# 259892  1.606840e+09  0xbd723fc4f1d737dcfc48a07fe7336766d34cad5f
# 893993  1.606840e+09  0xbd723fc4f1d737dcfc48a07fe7336766d34cad5f
#
#               userAlias                                  onBehalfOf  \
# 259892  Brooklyn Dingle                                         NaN
# 893993  Brooklyn Dingle  0xdcd33426ba191383f1c9b431a342498fdac73488
#
#         onBehalfOfAlias                                        pool reserve  \
# 259892              NaN  0xb53c1a33016b2dc2ff3653530bff1848a515c8c5    WETH
# 893993  Tracie Friedman  0xb53c1a33016b2dc2ff3653530bff1848a515c8c5    WETH
#
#         amount  ...  liquidatorAlias  priceInUsd  borrowRateModeTo  \
# 259892     NaN  ...              NaN         NaN               NaN
# 893993   0.001  ...              NaN         NaN               NaN
#
#        borrowRateModeFrom stableBorrowRate variableBorrowRate target  \
# 259892                NaN              NaN                NaN    NaN
# 893993                NaN              NaN                NaN    NaN
#
#         totalFee version  deployment
# 259892       NaN      V2     Mainnet
# 893993       NaN      V2     Mainnet
#
# [2 rows x 35 columns]
# Dynamic Transactions:
#                                                        id        type  \
# 0       0xc70f4c3f447f6a88e9fbb87ac1394b589e469ee57dda...      borrow
# 893995  0xcd650142f38eaa8304cd322f13f7721029ab1ac22ecb...     deposit
# 259896  0xaf5e3f50a65040286ce2a4092947c945b20e334ad911...  collateral
# 893994  0xaf5e3f50a65040286ce2a4092947c945b20e334ad911...     deposit
# 259893  0x25f636e7b49a599c765bcdac00853265ac76a5921953...  collateral
#
#            timestamp                                        user  \
# 0       1.606841e+09  0xbd723fc4f1d737dcfc48a07fe7336766d34cad5f
# 893995  1.606841e+09  0xbd723fc4f1d737dcfc48a07fe7336766d34cad5f
# 259896  1.606841e+09  0xbd723fc4f1d737dcfc48a07fe7336766d34cad5f
# 893994  1.606841e+09  0xbd723fc4f1d737dcfc48a07fe7336766d34cad5f
# 259893  1.606841e+09  0xbd723fc4f1d737dcfc48a07fe7336766d34cad5f
#
#               userAlias                                  onBehalfOf  \
# 0       Brooklyn Dingle  0xbd723fc4f1d737dcfc48a07fe7336766d34cad5f
# 893995  Brooklyn Dingle  0xbd723fc4f1d737dcfc48a07fe7336766d34cad5f
# 259896  Brooklyn Dingle                                         NaN
# 893994  Brooklyn Dingle  0xbd723fc4f1d737dcfc48a07fe7336766d34cad5f
# 259893  Brooklyn Dingle                                         NaN
#
#         onBehalfOfAlias                                        pool reserve  \
# 0       Brooklyn Dingle  0xb53c1a33016b2dc2ff3653530bff1848a515c8c5     DAI
# 893995  Brooklyn Dingle  0xb53c1a33016b2dc2ff3653530bff1848a515c8c5     DAI
# 259896              NaN  0xb53c1a33016b2dc2ff3653530bff1848a515c8c5     DAI
# 893994  Brooklyn Dingle  0xb53c1a33016b2dc2ff3653530bff1848a515c8c5     DAI
# 259893              NaN  0xb53c1a33016b2dc2ff3653530bff1848a515c8c5    WETH
#
#         amount  ...  liquidatorAlias  priceInUsd  borrowRateModeTo  \
# 0          1.0  ...              NaN         NaN               NaN
# 893995     1.0  ...              NaN         NaN               NaN
# 259896     NaN  ...              NaN         NaN               NaN
# 893994     3.0  ...              NaN         NaN               NaN
# 259893     NaN  ...              NaN         NaN               NaN
#
#        borrowRateModeFrom stableBorrowRate variableBorrowRate target  \
# 0                     NaN              NaN                NaN    NaN
# 893995                NaN              NaN                NaN    NaN
# 259896                NaN              NaN                NaN    NaN
# 893994                NaN              NaN                NaN    NaN
# 259893                NaN              NaN                NaN    NaN
#
#         totalFee version  deployment
# 0            NaN      V2     Mainnet
# 893995       NaN      V2     Mainnet
# 259896       NaN      V2     Mainnet
# 893994       NaN      V2     Mainnet
# 259893       NaN      V2     Mainnet
#
# [5 rows x 35 columns]
# ----------------------------------------
# IndexID: 0xae1083a26ffc90a681fc856b9bb087e37a16c037227a95b1230a06a972e37d5f
# Static Transactions:
#                                                        id        type  \
# 893995  0xcd650142f38eaa8304cd322f13f7721029ab1ac22ecb...     deposit
# 259896  0xaf5e3f50a65040286ce2a4092947c945b20e334ad911...  collateral
# 893994  0xaf5e3f50a65040286ce2a4092947c945b20e334ad911...     deposit
# 259893  0x25f636e7b49a599c765bcdac00853265ac76a5921953...  collateral
# 259892  0x870bf17a6373c10290d626134936230ada5f8ab0eee2...  collateral
# 893993  0x870bf17a6373c10290d626134936230ada5f8ab0eee2...     deposit
#
#            timestamp                                        user  \
# 893995  1.606841e+09  0xbd723fc4f1d737dcfc48a07fe7336766d34cad5f
# 259896  1.606841e+09  0xbd723fc4f1d737dcfc48a07fe7336766d34cad5f
# 893994  1.606841e+09  0xbd723fc4f1d737dcfc48a07fe7336766d34cad5f
# 259893  1.606841e+09  0xbd723fc4f1d737dcfc48a07fe7336766d34cad5f
# 259892  1.606840e+09  0xbd723fc4f1d737dcfc48a07fe7336766d34cad5f
# 893993  1.606840e+09  0xbd723fc4f1d737dcfc48a07fe7336766d34cad5f
#
#               userAlias                                  onBehalfOf  \
# 893995  Brooklyn Dingle  0xbd723fc4f1d737dcfc48a07fe7336766d34cad5f
# 259896  Brooklyn Dingle                                         NaN
# 893994  Brooklyn Dingle  0xbd723fc4f1d737dcfc48a07fe7336766d34cad5f
# 259893  Brooklyn Dingle                                         NaN
# 259892  Brooklyn Dingle                                         NaN
# 893993  Brooklyn Dingle  0xdcd33426ba191383f1c9b431a342498fdac73488
#
#         onBehalfOfAlias                                        pool reserve  \
# 893995  Brooklyn Dingle  0xb53c1a33016b2dc2ff3653530bff1848a515c8c5     DAI
# 259896              NaN  0xb53c1a33016b2dc2ff3653530bff1848a515c8c5     DAI
# 893994  Brooklyn Dingle  0xb53c1a33016b2dc2ff3653530bff1848a515c8c5     DAI
# 259893              NaN  0xb53c1a33016b2dc2ff3653530bff1848a515c8c5    WETH
# 259892              NaN  0xb53c1a33016b2dc2ff3653530bff1848a515c8c5    WETH
# 893993  Tracie Friedman  0xb53c1a33016b2dc2ff3653530bff1848a515c8c5    WETH
#
#         amount  ...  liquidatorAlias  priceInUsd  borrowRateModeTo  \
# 893995   1.000  ...              NaN         NaN               NaN
# 259896     NaN  ...              NaN         NaN               NaN
# 893994   3.000  ...              NaN         NaN               NaN
# 259893     NaN  ...              NaN         NaN               NaN
# 259892     NaN  ...              NaN         NaN               NaN
# 893993   0.001  ...              NaN         NaN               NaN
#
#        borrowRateModeFrom stableBorrowRate variableBorrowRate target  \
# 893995                NaN              NaN                NaN    NaN
# 259896                NaN              NaN                NaN    NaN
# 893994                NaN              NaN                NaN    NaN
# 259893                NaN              NaN                NaN    NaN
# 259892                NaN              NaN                NaN    NaN
# 893993                NaN              NaN                NaN    NaN
#
#         totalFee version  deployment
# 893995       NaN      V2     Mainnet
# 259896       NaN      V2     Mainnet
# 893994       NaN      V2     Mainnet
# 259893       NaN      V2     Mainnet
# 259892       NaN      V2     Mainnet
# 893993       NaN      V2     Mainnet
#
# [6 rows x 35 columns]
# Dynamic Transactions:
#                                                         id        type  \
# 259903   0x1e4954fa24e853ee3fef61c20f5040132f7ff82799c4...  collateral
# 894003   0x1e4954fa24e853ee3fef61c20f5040132f7ff82799c4...     deposit
# 893996   0x94bea79e5d985f5b440d6389773af5efdec428a7e401...     deposit
# 1406853  0x17869b1999e221cb74ab4fc8c9f7087097e6e27b50dd...    withdraw
# 0        0xc70f4c3f447f6a88e9fbb87ac1394b589e469ee57dda...      borrow
#
#             timestamp                                        user  \
# 259903   1.606913e+09  0xbd723fc4f1d737dcfc48a07fe7336766d34cad5f
# 894003   1.606913e+09  0xbd723fc4f1d737dcfc48a07fe7336766d34cad5f
# 893996   1.606842e+09  0xbd723fc4f1d737dcfc48a07fe7336766d34cad5f
# 1406853  1.606841e+09  0xbd723fc4f1d737dcfc48a07fe7336766d34cad5f
# 0        1.606841e+09  0xbd723fc4f1d737dcfc48a07fe7336766d34cad5f
#
#                userAlias                                  onBehalfOf  \
# 259903   Brooklyn Dingle                                         NaN
# 894003   Brooklyn Dingle  0xbd723fc4f1d737dcfc48a07fe7336766d34cad5f
# 893996   Brooklyn Dingle  0xbd723fc4f1d737dcfc48a07fe7336766d34cad5f
# 1406853  Brooklyn Dingle  0xbd723fc4f1d737dcfc48a07fe7336766d34cad5f
# 0        Brooklyn Dingle  0xbd723fc4f1d737dcfc48a07fe7336766d34cad5f
#
#          onBehalfOfAlias                                        pool reserve  \
# 259903               NaN  0xb53c1a33016b2dc2ff3653530bff1848a515c8c5     MKR
# 894003   Brooklyn Dingle  0xb53c1a33016b2dc2ff3653530bff1848a515c8c5     MKR
# 893996   Brooklyn Dingle  0xb53c1a33016b2dc2ff3653530bff1848a515c8c5     DAI
# 1406853  Brooklyn Dingle  0xb53c1a33016b2dc2ff3653530bff1848a515c8c5     DAI
# 0        Brooklyn Dingle  0xb53c1a33016b2dc2ff3653530bff1848a515c8c5     DAI
#
#          amount  ...  liquidatorAlias  priceInUsd  borrowRateModeTo  \
# 259903      NaN  ...              NaN         NaN               NaN
# 894003    0.001  ...              NaN         NaN               NaN
# 893996    1.000  ...              NaN         NaN               NaN
# 1406853   1.000  ...              NaN    1.001646               NaN
# 0         1.000  ...              NaN         NaN               NaN
#
#         borrowRateModeFrom stableBorrowRate variableBorrowRate target  \
# 259903                 NaN              NaN                NaN    NaN
# 894003                 NaN              NaN                NaN    NaN
# 893996                 NaN              NaN                NaN    NaN
# 1406853                NaN              NaN                NaN    NaN
# 0                      NaN              NaN                NaN    NaN
#
#          totalFee version  deployment
# 259903        NaN      V2     Mainnet
# 894003        NaN      V2     Mainnet
# 893996        NaN      V2     Mainnet
# 1406853       NaN      V2     Mainnet
# 0             NaN      V2     Mainnet
#
# [5 rows x 35 columns]
# ----------------------------------------
# IndexID: 0xd12cbbad05aa4b7dbcf62ee862bf07c73ddfca58f035b16bebf5bcfd6efa1289
# Static Transactions:
# Empty DataFrame
# Columns: [id, type, timestamp, user, userAlias, onBehalfOf, onBehalfOfAlias, pool, reserve, amount, amountUSD, amountETH, borrowRate, borrowRateMode, fromState, toState, liquidator, principalAmount, principalReserve, principalAmountUSD, principalAmountETH, collateralAmount, collateralReserve, collateralAmountUSD, collateralAmountETH, liquidatorAlias, priceInUsd, borrowRateModeTo, borrowRateModeFrom, stableBorrowRate, variableBorrowRate, target, totalFee, version, deployment]
# Index: []
#
# [0 rows x 35 columns]
# Dynamic Transactions:
#                                                        id        type  \
# 1       0x1ee3db904548c16d2ed3572f3d9894652e031facc8fa...      borrow
# 259897  0x83362b03f36923c55c6ae839e19e991ba60e2428b71e...  collateral
# 893997  0x83362b03f36923c55c6ae839e19e991ba60e2428b71e...     deposit
#
#            timestamp                                        user  \
# 1       1.606902e+09  0x21d05071ca08593e13cd3afd0b4869537e015c92
# 259897  1.606901e+09  0x21d05071ca08593e13cd3afd0b4869537e015c92
# 893997  1.606901e+09  0x21d05071ca08593e13cd3afd0b4869537e015c92
#
#                userAlias                                  onBehalfOf  \
# 1       Cassandrea Xiong  0x21d05071ca08593e13cd3afd0b4869537e015c92
# 259897  Cassandrea Xiong                                         NaN
# 893997  Cassandrea Xiong  0x21d05071ca08593e13cd3afd0b4869537e015c92
#
#          onBehalfOfAlias                                        pool reserve  \
# 1       Cassandrea Xiong  0xb53c1a33016b2dc2ff3653530bff1848a515c8c5     DAI
# 259897               NaN  0xb53c1a33016b2dc2ff3653530bff1848a515c8c5    LINK
# 893997  Cassandrea Xiong  0xb53c1a33016b2dc2ff3653530bff1848a515c8c5    LINK
#
#           amount  ...  liquidatorAlias  priceInUsd  borrowRateModeTo  \
# 1       1.000000  ...              NaN         NaN               NaN
# 259897       NaN  ...              NaN         NaN               NaN
# 893997  1.782007  ...              NaN         NaN               NaN
#
#        borrowRateModeFrom stableBorrowRate variableBorrowRate target  \
# 1                     NaN              NaN                NaN    NaN
# 259897                NaN              NaN                NaN    NaN
# 893997                NaN              NaN                NaN    NaN
#
#         totalFee version  deployment
# 1            NaN      V2     Mainnet
# 259897       NaN      V2     Mainnet
# 893997       NaN      V2     Mainnet
#
# [3 rows x 35 columns]
# ----------------------------------------
# IndexID: 0x3494b18562a99af7485ca5663f084b65ea6b1bc1bebc0d1dd88ef5901ba5405a
# Static Transactions:
#                                                         id        type  \
# 1780066  0x4c3338fe9155dbddecca66e077bd8bfe9965ec12e2b0...       repay
# 2        0x1e8f85330edc5005ead7a7ae8c418fbb64df726d4ffc...      borrow
# 259900   0x2dc0a5f7359297fbf24fb88665f59aa28e86b257863e...  collateral
# 894000   0x2dc0a5f7359297fbf24fb88665f59aa28e86b257863e...     deposit
# 259899   0xa1c814bc812a415d347d55aea4e01b8371aef178647b...  collateral
# 893999   0xa1c814bc812a415d347d55aea4e01b8371aef178647b...     deposit
# 259898   0x0ec4eb191b1167f35abbeca76e33e8d2729c2e41be13...  collateral
# 893998   0x0ec4eb191b1167f35abbeca76e33e8d2729c2e41be13...     deposit
#
#             timestamp                                        user  \
# 1780066  1.606906e+09  0x39d637737cc76c5849a52c7d3b872a1eb22aa71c
# 2        1.606905e+09  0x39d637737cc76c5849a52c7d3b872a1eb22aa71c
# 259900   1.606904e+09  0x39d637737cc76c5849a52c7d3b872a1eb22aa71c
# 894000   1.606904e+09  0x39d637737cc76c5849a52c7d3b872a1eb22aa71c
# 259899   1.606904e+09  0x39d637737cc76c5849a52c7d3b872a1eb22aa71c
# 893999   1.606904e+09  0x39d637737cc76c5849a52c7d3b872a1eb22aa71c
# 259898   1.606904e+09  0x39d637737cc76c5849a52c7d3b872a1eb22aa71c
# 893998   1.606904e+09  0x39d637737cc76c5849a52c7d3b872a1eb22aa71c
#
#               userAlias                                  onBehalfOf  \
# 1780066  Brian Castillo  0x39d637737cc76c5849a52c7d3b872a1eb22aa71c
# 2        Brian Castillo  0x39d637737cc76c5849a52c7d3b872a1eb22aa71c
# 259900   Brian Castillo                                         NaN
# 894000   Brian Castillo  0x39d637737cc76c5849a52c7d3b872a1eb22aa71c
# 259899   Brian Castillo                                         NaN
# 893999   Brian Castillo  0xdcd33426ba191383f1c9b431a342498fdac73488
# 259898   Brian Castillo                                         NaN
# 893998   Brian Castillo  0x39d637737cc76c5849a52c7d3b872a1eb22aa71c
#
#          onBehalfOfAlias                                        pool reserve  \
# 1780066   Brian Castillo  0xb53c1a33016b2dc2ff3653530bff1848a515c8c5    LINK
# 2         Brian Castillo  0xb53c1a33016b2dc2ff3653530bff1848a515c8c5    LINK
# 259900               NaN  0xb53c1a33016b2dc2ff3653530bff1848a515c8c5    USDT
# 894000    Brian Castillo  0xb53c1a33016b2dc2ff3653530bff1848a515c8c5    USDT
# 259899               NaN  0xb53c1a33016b2dc2ff3653530bff1848a515c8c5    WETH
# 893999   Tracie Friedman  0xb53c1a33016b2dc2ff3653530bff1848a515c8c5    WETH
# 259898               NaN  0xb53c1a33016b2dc2ff3653530bff1848a515c8c5     DAI
# 893998    Brian Castillo  0xb53c1a33016b2dc2ff3653530bff1848a515c8c5     DAI
#
#          amount  ...  liquidatorAlias  priceInUsd  borrowRateModeTo  \
# 1780066     1.0  ...              NaN   12.761559               NaN
# 2           1.0  ...              NaN         NaN               NaN
# 259900      NaN  ...              NaN         NaN               NaN
# 894000    250.0  ...              NaN         NaN               NaN
# 259899      NaN  ...              NaN         NaN               NaN
# 893999      0.5  ...              NaN         NaN               NaN
# 259898      NaN  ...              NaN         NaN               NaN
# 893998    100.0  ...              NaN         NaN               NaN
#
#         borrowRateModeFrom stableBorrowRate variableBorrowRate target  \
# 1780066                NaN              NaN                NaN    NaN
# 2                      NaN              NaN                NaN    NaN
# 259900                 NaN              NaN                NaN    NaN
# 894000                 NaN              NaN                NaN    NaN
# 259899                 NaN              NaN                NaN    NaN
# 893999                 NaN              NaN                NaN    NaN
# 259898                 NaN              NaN                NaN    NaN
# 893998                 NaN              NaN                NaN    NaN
#
#          totalFee version  deployment
# 1780066       NaN      V2     Mainnet
# 2             NaN      V2     Mainnet
# 259900        NaN      V2     Mainnet
# 894000        NaN      V2     Mainnet
# 259899        NaN      V2     Mainnet
# 893999        NaN      V2     Mainnet
# 259898        NaN      V2     Mainnet
# 893998        NaN      V2     Mainnet
#
# [8 rows x 35 columns]
# Dynamic Transactions:
#                                                    id    type     timestamp  \
# 21  0x4191d90940be6bf98bd4b7b9ca2f86d2a1dec44ecbec...  borrow  1.606925e+09
# 18  0x1f39325b14fb96c93b48f722aa8be2109be88a79a8e9...  borrow  1.606925e+09
# 17  0xe64d208024d04bbea7100441d5cf5272bcb77f45b30a...  borrow  1.606924e+09
# 5   0xb287043d2ef102bb10acd5bb8e8a8e4facac3df6c534...  borrow  1.606917e+09
# 3   0x43136c7aba13c072bb19ed88f8eadf859f0bfb994b42...  borrow  1.606913e+09
#
#                                           user       userAlias  \
# 21  0x39d637737cc76c5849a52c7d3b872a1eb22aa71c  Brian Castillo
# 18  0x39d637737cc76c5849a52c7d3b872a1eb22aa71c  Brian Castillo
# 17  0x39d637737cc76c5849a52c7d3b872a1eb22aa71c  Brian Castillo
# 5   0x39d637737cc76c5849a52c7d3b872a1eb22aa71c  Brian Castillo
# 3   0x39d637737cc76c5849a52c7d3b872a1eb22aa71c  Brian Castillo
#
#                                     onBehalfOf  onBehalfOfAlias  \
# 21  0x39d637737cc76c5849a52c7d3b872a1eb22aa71c   Brian Castillo
# 18  0xdcd33426ba191383f1c9b431a342498fdac73488  Tracie Friedman
# 17  0x39d637737cc76c5849a52c7d3b872a1eb22aa71c   Brian Castillo
# 5   0x39d637737cc76c5849a52c7d3b872a1eb22aa71c   Brian Castillo
# 3   0x39d637737cc76c5849a52c7d3b872a1eb22aa71c   Brian Castillo
#
#                                           pool reserve    amount  ...  \
# 21  0xb53c1a33016b2dc2ff3653530bff1848a515c8c5     UNI  10.00000  ...
# 18  0xb53c1a33016b2dc2ff3653530bff1848a515c8c5    WETH   0.10000  ...
# 17  0xb53c1a33016b2dc2ff3653530bff1848a515c8c5     YFI   0.00010  ...
# 5   0xb53c1a33016b2dc2ff3653530bff1848a515c8c5    WBTC   0.00001  ...
# 3   0xb53c1a33016b2dc2ff3653530bff1848a515c8c5    AAVE   0.05000  ...
#
#     liquidatorAlias  priceInUsd  borrowRateModeTo borrowRateModeFrom  \
# 21              NaN         NaN               NaN                NaN
# 18              NaN         NaN               NaN                NaN
# 17              NaN         NaN               NaN                NaN
# 5               NaN         NaN               NaN                NaN
# 3               NaN         NaN               NaN                NaN
#
#    stableBorrowRate variableBorrowRate target  totalFee version  deployment
# 21              NaN                NaN    NaN       NaN      V2     Mainnet
# 18              NaN                NaN    NaN       NaN      V2     Mainnet
# 17              NaN                NaN    NaN       NaN      V2     Mainnet
# 5               NaN                NaN    NaN       NaN      V2     Mainnet
# 3               NaN                NaN    NaN       NaN      V2     Mainnet
#
# [5 rows x 35 columns]
# ----------------------------------------
# IndexID: 0x9338a176dd5d83a988f4f3e1433e54c369f27f21d0aac63c7d83dd3bc18c97a2
# Static Transactions:
#                                                         id        type  \
# 5        0xb287043d2ef102bb10acd5bb8e8a8e4facac3df6c534...      borrow
# 3        0x43136c7aba13c072bb19ed88f8eadf859f0bfb994b42...      borrow
# 1780066  0x4c3338fe9155dbddecca66e077bd8bfe9965ec12e2b0...       repay
# 2        0x1e8f85330edc5005ead7a7ae8c418fbb64df726d4ffc...      borrow
# 259900   0x2dc0a5f7359297fbf24fb88665f59aa28e86b257863e...  collateral
# 894000   0x2dc0a5f7359297fbf24fb88665f59aa28e86b257863e...     deposit
# 259899   0xa1c814bc812a415d347d55aea4e01b8371aef178647b...  collateral
# 893999   0xa1c814bc812a415d347d55aea4e01b8371aef178647b...     deposit
# 259898   0x0ec4eb191b1167f35abbeca76e33e8d2729c2e41be13...  collateral
# 893998   0x0ec4eb191b1167f35abbeca76e33e8d2729c2e41be13...     deposit
#
#             timestamp                                        user  \
# 5        1.606917e+09  0x39d637737cc76c5849a52c7d3b872a1eb22aa71c
# 3        1.606913e+09  0x39d637737cc76c5849a52c7d3b872a1eb22aa71c
# 1780066  1.606906e+09  0x39d637737cc76c5849a52c7d3b872a1eb22aa71c
# 2        1.606905e+09  0x39d637737cc76c5849a52c7d3b872a1eb22aa71c
# 259900   1.606904e+09  0x39d637737cc76c5849a52c7d3b872a1eb22aa71c
# 894000   1.606904e+09  0x39d637737cc76c5849a52c7d3b872a1eb22aa71c
# 259899   1.606904e+09  0x39d637737cc76c5849a52c7d3b872a1eb22aa71c
# 893999   1.606904e+09  0x39d637737cc76c5849a52c7d3b872a1eb22aa71c
# 259898   1.606904e+09  0x39d637737cc76c5849a52c7d3b872a1eb22aa71c
# 893998   1.606904e+09  0x39d637737cc76c5849a52c7d3b872a1eb22aa71c
#
#               userAlias                                  onBehalfOf  \
# 5        Brian Castillo  0x39d637737cc76c5849a52c7d3b872a1eb22aa71c
# 3        Brian Castillo  0x39d637737cc76c5849a52c7d3b872a1eb22aa71c
# 1780066  Brian Castillo  0x39d637737cc76c5849a52c7d3b872a1eb22aa71c
# 2        Brian Castillo  0x39d637737cc76c5849a52c7d3b872a1eb22aa71c
# 259900   Brian Castillo                                         NaN
# 894000   Brian Castillo  0x39d637737cc76c5849a52c7d3b872a1eb22aa71c
# 259899   Brian Castillo                                         NaN
# 893999   Brian Castillo  0xdcd33426ba191383f1c9b431a342498fdac73488
# 259898   Brian Castillo                                         NaN
# 893998   Brian Castillo  0x39d637737cc76c5849a52c7d3b872a1eb22aa71c
#
#          onBehalfOfAlias                                        pool reserve  \
# 5         Brian Castillo  0xb53c1a33016b2dc2ff3653530bff1848a515c8c5    WBTC
# 3         Brian Castillo  0xb53c1a33016b2dc2ff3653530bff1848a515c8c5    AAVE
# 1780066   Brian Castillo  0xb53c1a33016b2dc2ff3653530bff1848a515c8c5    LINK
# 2         Brian Castillo  0xb53c1a33016b2dc2ff3653530bff1848a515c8c5    LINK
# 259900               NaN  0xb53c1a33016b2dc2ff3653530bff1848a515c8c5    USDT
# 894000    Brian Castillo  0xb53c1a33016b2dc2ff3653530bff1848a515c8c5    USDT
# 259899               NaN  0xb53c1a33016b2dc2ff3653530bff1848a515c8c5    WETH
# 893999   Tracie Friedman  0xb53c1a33016b2dc2ff3653530bff1848a515c8c5    WETH
# 259898               NaN  0xb53c1a33016b2dc2ff3653530bff1848a515c8c5     DAI
# 893998    Brian Castillo  0xb53c1a33016b2dc2ff3653530bff1848a515c8c5     DAI
#
#             amount  ...  liquidatorAlias  priceInUsd  borrowRateModeTo  \
# 5          0.00001  ...              NaN         NaN               NaN
# 3          0.05000  ...              NaN         NaN               NaN
# 1780066    1.00000  ...              NaN   12.761559               NaN
# 2          1.00000  ...              NaN         NaN               NaN
# 259900         NaN  ...              NaN         NaN               NaN
# 894000   250.00000  ...              NaN         NaN               NaN
# 259899         NaN  ...              NaN         NaN               NaN
# 893999     0.50000  ...              NaN         NaN               NaN
# 259898         NaN  ...              NaN         NaN               NaN
# 893998   100.00000  ...              NaN         NaN               NaN
#
#         borrowRateModeFrom stableBorrowRate variableBorrowRate target  \
# 5                      NaN              NaN                NaN    NaN
# 3                      NaN              NaN                NaN    NaN
# 1780066                NaN              NaN                NaN    NaN
# 2                      NaN              NaN                NaN    NaN
# 259900                 NaN              NaN                NaN    NaN
# 894000                 NaN              NaN                NaN    NaN
# 259899                 NaN              NaN                NaN    NaN
# 893999                 NaN              NaN                NaN    NaN
# 259898                 NaN              NaN                NaN    NaN
# 893998                 NaN              NaN                NaN    NaN
#
#          totalFee version  deployment
# 5             NaN      V2     Mainnet
# 3             NaN      V2     Mainnet
# 1780066       NaN      V2     Mainnet
# 2             NaN      V2     Mainnet
# 259900        NaN      V2     Mainnet
# 894000        NaN      V2     Mainnet
# 259899        NaN      V2     Mainnet
# 893999        NaN      V2     Mainnet
# 259898        NaN      V2     Mainnet
# 893998        NaN      V2     Mainnet
#
# [10 rows x 35 columns]
# Dynamic Transactions:
#                                                        id        type  \
# 259928  0x3494b18562a99af7485ca5663f084b65ea6b1bc1bebc...  collateral
# 894023  0x3494b18562a99af7485ca5663f084b65ea6b1bc1bebc...     deposit
# 21      0x4191d90940be6bf98bd4b7b9ca2f86d2a1dec44ecbec...      borrow
# 18      0x1f39325b14fb96c93b48f722aa8be2109be88a79a8e9...      borrow
# 17      0xe64d208024d04bbea7100441d5cf5272bcb77f45b30a...      borrow
#
#            timestamp                                        user  \
# 259928  1.606925e+09  0x39d637737cc76c5849a52c7d3b872a1eb22aa71c
# 894023  1.606925e+09  0x39d637737cc76c5849a52c7d3b872a1eb22aa71c
# 21      1.606925e+09  0x39d637737cc76c5849a52c7d3b872a1eb22aa71c
# 18      1.606925e+09  0x39d637737cc76c5849a52c7d3b872a1eb22aa71c
# 17      1.606924e+09  0x39d637737cc76c5849a52c7d3b872a1eb22aa71c
#
#              userAlias                                  onBehalfOf  \
# 259928  Brian Castillo                                         NaN
# 894023  Brian Castillo  0x5e2f9d998ba3392bad87fa058e4fbd97797edb48
# 21      Brian Castillo  0x39d637737cc76c5849a52c7d3b872a1eb22aa71c
# 18      Brian Castillo  0xdcd33426ba191383f1c9b431a342498fdac73488
# 17      Brian Castillo  0x39d637737cc76c5849a52c7d3b872a1eb22aa71c
#
#         onBehalfOfAlias                                        pool reserve  \
# 259928              NaN  0xb53c1a33016b2dc2ff3653530bff1848a515c8c5    USDC
# 894023        Kiah Muya  0xb53c1a33016b2dc2ff3653530bff1848a515c8c5    USDC
# 21       Brian Castillo  0xb53c1a33016b2dc2ff3653530bff1848a515c8c5     UNI
# 18      Tracie Friedman  0xb53c1a33016b2dc2ff3653530bff1848a515c8c5    WETH
# 17       Brian Castillo  0xb53c1a33016b2dc2ff3653530bff1848a515c8c5     YFI
#
#          amount  ...  liquidatorAlias  priceInUsd  borrowRateModeTo  \
# 259928      NaN  ...              NaN         NaN               NaN
# 894023  99.8801  ...              NaN         NaN               NaN
# 21      10.0000  ...              NaN         NaN               NaN
# 18       0.1000  ...              NaN         NaN               NaN
# 17       0.0001  ...              NaN         NaN               NaN
#
#        borrowRateModeFrom stableBorrowRate variableBorrowRate target  \
# 259928                NaN              NaN                NaN    NaN
# 894023                NaN              NaN                NaN    NaN
# 21                    NaN              NaN                NaN    NaN
# 18                    NaN              NaN                NaN    NaN
# 17                    NaN              NaN                NaN    NaN
#
#         totalFee version  deployment
# 259928       NaN      V2     Mainnet
# 894023       NaN      V2     Mainnet
# 21           NaN      V2     Mainnet
# 18           NaN      V2     Mainnet
# 17           NaN      V2     Mainnet
#
# [5 rows x 35 columns]
# ----------------------------------------
# IndexID: 0x24f391b0cfabb77718df725e9700d4134387b7ecc6002863488e24775c75016b
# Static Transactions:
#                                                         id        type  \
# 18       0x1f39325b14fb96c93b48f722aa8be2109be88a79a8e9...      borrow
# 17       0xe64d208024d04bbea7100441d5cf5272bcb77f45b30a...      borrow
# 5        0xb287043d2ef102bb10acd5bb8e8a8e4facac3df6c534...      borrow
# 3        0x43136c7aba13c072bb19ed88f8eadf859f0bfb994b42...      borrow
# 1780066  0x4c3338fe9155dbddecca66e077bd8bfe9965ec12e2b0...       repay
# 2        0x1e8f85330edc5005ead7a7ae8c418fbb64df726d4ffc...      borrow
# 894000   0x2dc0a5f7359297fbf24fb88665f59aa28e86b257863e...     deposit
# 259900   0x2dc0a5f7359297fbf24fb88665f59aa28e86b257863e...  collateral
# 893999   0xa1c814bc812a415d347d55aea4e01b8371aef178647b...     deposit
# 259899   0xa1c814bc812a415d347d55aea4e01b8371aef178647b...  collateral
# 893998   0x0ec4eb191b1167f35abbeca76e33e8d2729c2e41be13...     deposit
# 259898   0x0ec4eb191b1167f35abbeca76e33e8d2729c2e41be13...  collateral
#
#             timestamp                                        user  \
# 18       1.606925e+09  0x39d637737cc76c5849a52c7d3b872a1eb22aa71c
# 17       1.606924e+09  0x39d637737cc76c5849a52c7d3b872a1eb22aa71c
# 5        1.606917e+09  0x39d637737cc76c5849a52c7d3b872a1eb22aa71c
# 3        1.606913e+09  0x39d637737cc76c5849a52c7d3b872a1eb22aa71c
# 1780066  1.606906e+09  0x39d637737cc76c5849a52c7d3b872a1eb22aa71c
# 2        1.606905e+09  0x39d637737cc76c5849a52c7d3b872a1eb22aa71c
# 894000   1.606904e+09  0x39d637737cc76c5849a52c7d3b872a1eb22aa71c
# 259900   1.606904e+09  0x39d637737cc76c5849a52c7d3b872a1eb22aa71c
# 893999   1.606904e+09  0x39d637737cc76c5849a52c7d3b872a1eb22aa71c
# 259899   1.606904e+09  0x39d637737cc76c5849a52c7d3b872a1eb22aa71c
# 893998   1.606904e+09  0x39d637737cc76c5849a52c7d3b872a1eb22aa71c
# 259898   1.606904e+09  0x39d637737cc76c5849a52c7d3b872a1eb22aa71c
#
#               userAlias                                  onBehalfOf  \
# 18       Brian Castillo  0xdcd33426ba191383f1c9b431a342498fdac73488
# 17       Brian Castillo  0x39d637737cc76c5849a52c7d3b872a1eb22aa71c
# 5        Brian Castillo  0x39d637737cc76c5849a52c7d3b872a1eb22aa71c
# 3        Brian Castillo  0x39d637737cc76c5849a52c7d3b872a1eb22aa71c
# 1780066  Brian Castillo  0x39d637737cc76c5849a52c7d3b872a1eb22aa71c
# 2        Brian Castillo  0x39d637737cc76c5849a52c7d3b872a1eb22aa71c
# 894000   Brian Castillo  0x39d637737cc76c5849a52c7d3b872a1eb22aa71c
# 259900   Brian Castillo                                         NaN
# 893999   Brian Castillo  0xdcd33426ba191383f1c9b431a342498fdac73488
# 259899   Brian Castillo                                         NaN
# 893998   Brian Castillo  0x39d637737cc76c5849a52c7d3b872a1eb22aa71c
# 259898   Brian Castillo                                         NaN
#
#          onBehalfOfAlias                                        pool reserve  \
# 18       Tracie Friedman  0xb53c1a33016b2dc2ff3653530bff1848a515c8c5    WETH
# 17        Brian Castillo  0xb53c1a33016b2dc2ff3653530bff1848a515c8c5     YFI
# 5         Brian Castillo  0xb53c1a33016b2dc2ff3653530bff1848a515c8c5    WBTC
# 3         Brian Castillo  0xb53c1a33016b2dc2ff3653530bff1848a515c8c5    AAVE
# 1780066   Brian Castillo  0xb53c1a33016b2dc2ff3653530bff1848a515c8c5    LINK
# 2         Brian Castillo  0xb53c1a33016b2dc2ff3653530bff1848a515c8c5    LINK
# 894000    Brian Castillo  0xb53c1a33016b2dc2ff3653530bff1848a515c8c5    USDT
# 259900               NaN  0xb53c1a33016b2dc2ff3653530bff1848a515c8c5    USDT
# 893999   Tracie Friedman  0xb53c1a33016b2dc2ff3653530bff1848a515c8c5    WETH
# 259899               NaN  0xb53c1a33016b2dc2ff3653530bff1848a515c8c5    WETH
# 893998    Brian Castillo  0xb53c1a33016b2dc2ff3653530bff1848a515c8c5     DAI
# 259898               NaN  0xb53c1a33016b2dc2ff3653530bff1848a515c8c5     DAI
#
#             amount  ...  liquidatorAlias  priceInUsd  borrowRateModeTo  \
# 18         0.10000  ...              NaN         NaN               NaN
# 17         0.00010  ...              NaN         NaN               NaN
# 5          0.00001  ...              NaN         NaN               NaN
# 3          0.05000  ...              NaN         NaN               NaN
# 1780066    1.00000  ...              NaN   12.761559               NaN
# 2          1.00000  ...              NaN         NaN               NaN
# 894000   250.00000  ...              NaN         NaN               NaN
# 259900         NaN  ...              NaN         NaN               NaN
# 893999     0.50000  ...              NaN         NaN               NaN
# 259899         NaN  ...              NaN         NaN               NaN
# 893998   100.00000  ...              NaN         NaN               NaN
# 259898         NaN  ...              NaN         NaN               NaN
#
#         borrowRateModeFrom stableBorrowRate variableBorrowRate target  \
# 18                     NaN              NaN                NaN    NaN
# 17                     NaN              NaN                NaN    NaN
# 5                      NaN              NaN                NaN    NaN
# 3                      NaN              NaN                NaN    NaN
# 1780066                NaN              NaN                NaN    NaN
# 2                      NaN              NaN                NaN    NaN
# 894000                 NaN              NaN                NaN    NaN
# 259900                 NaN              NaN                NaN    NaN
# 893999                 NaN              NaN                NaN    NaN
# 259899                 NaN              NaN                NaN    NaN
# 893998                 NaN              NaN                NaN    NaN
# 259898                 NaN              NaN                NaN    NaN
#
#          totalFee version  deployment
# 18            NaN      V2     Mainnet
# 17            NaN      V2     Mainnet
# 5             NaN      V2     Mainnet
# 3             NaN      V2     Mainnet
# 1780066       NaN      V2     Mainnet
# 2             NaN      V2     Mainnet
# 894000        NaN      V2     Mainnet
# 259900        NaN      V2     Mainnet
# 893999        NaN      V2     Mainnet
# 259899        NaN      V2     Mainnet
# 893998        NaN      V2     Mainnet
# 259898        NaN      V2     Mainnet
#
# [12 rows x 35 columns]
# Dynamic Transactions:
#                                                        id        type  \
# 894024  0x9338a176dd5d83a988f4f3e1433e54c369f27f21d0aa...     deposit
# 259931  0x9338a176dd5d83a988f4f3e1433e54c369f27f21d0aa...  collateral
# 894023  0x3494b18562a99af7485ca5663f084b65ea6b1bc1bebc...     deposit
# 259928  0x3494b18562a99af7485ca5663f084b65ea6b1bc1bebc...  collateral
# 21      0x4191d90940be6bf98bd4b7b9ca2f86d2a1dec44ecbec...      borrow
#
#            timestamp                                        user  \
# 894024  1.606926e+09  0x39d637737cc76c5849a52c7d3b872a1eb22aa71c
# 259931  1.606926e+09  0x39d637737cc76c5849a52c7d3b872a1eb22aa71c
# 894023  1.606925e+09  0x39d637737cc76c5849a52c7d3b872a1eb22aa71c
# 259928  1.606925e+09  0x39d637737cc76c5849a52c7d3b872a1eb22aa71c
# 21      1.606925e+09  0x39d637737cc76c5849a52c7d3b872a1eb22aa71c
#
#              userAlias                                  onBehalfOf  \
# 894024  Brian Castillo  0x5e2f9d998ba3392bad87fa058e4fbd97797edb48
# 259931  Brian Castillo                                         NaN
# 894023  Brian Castillo  0x5e2f9d998ba3392bad87fa058e4fbd97797edb48
# 259928  Brian Castillo                                         NaN
# 21      Brian Castillo  0x39d637737cc76c5849a52c7d3b872a1eb22aa71c
#
#        onBehalfOfAlias                                        pool reserve  \
# 894024       Kiah Muya  0xb53c1a33016b2dc2ff3653530bff1848a515c8c5    TUSD
# 259931             NaN  0xb53c1a33016b2dc2ff3653530bff1848a515c8c5    TUSD
# 894023       Kiah Muya  0xb53c1a33016b2dc2ff3653530bff1848a515c8c5    USDC
# 259928             NaN  0xb53c1a33016b2dc2ff3653530bff1848a515c8c5    USDC
# 21      Brian Castillo  0xb53c1a33016b2dc2ff3653530bff1848a515c8c5     UNI
#
#           amount  ...  liquidatorAlias  priceInUsd  borrowRateModeTo  \
# 894024  49.94298  ...              NaN         NaN               NaN
# 259931       NaN  ...              NaN         NaN               NaN
# 894023  99.88010  ...              NaN         NaN               NaN
# 259928       NaN  ...              NaN         NaN               NaN
# 21      10.00000  ...              NaN         NaN               NaN
#
#        borrowRateModeFrom stableBorrowRate variableBorrowRate target  \
# 894024                NaN              NaN                NaN    NaN
# 259931                NaN              NaN                NaN    NaN
# 894023                NaN              NaN                NaN    NaN
# 259928                NaN              NaN                NaN    NaN
# 21                    NaN              NaN                NaN    NaN
#
#         totalFee version  deployment
# 894024       NaN      V2     Mainnet
# 259931       NaN      V2     Mainnet
# 894023       NaN      V2     Mainnet
# 259928       NaN      V2     Mainnet
# 21           NaN      V2     Mainnet
#
# [5 rows x 35 columns]
# ----------------------------------------
# IndexID: 0x994098978ce2691bbf6d71e4df9ae936997a5e9453a80d2ad0338b4241ee34c8
# Static Transactions:
#                                                         id        type  \
# 21       0x4191d90940be6bf98bd4b7b9ca2f86d2a1dec44ecbec...      borrow
# 18       0x1f39325b14fb96c93b48f722aa8be2109be88a79a8e9...      borrow
# 17       0xe64d208024d04bbea7100441d5cf5272bcb77f45b30a...      borrow
# 5        0xb287043d2ef102bb10acd5bb8e8a8e4facac3df6c534...      borrow
# 3        0x43136c7aba13c072bb19ed88f8eadf859f0bfb994b42...      borrow
# 1780066  0x4c3338fe9155dbddecca66e077bd8bfe9965ec12e2b0...       repay
# 2        0x1e8f85330edc5005ead7a7ae8c418fbb64df726d4ffc...      borrow
# 894000   0x2dc0a5f7359297fbf24fb88665f59aa28e86b257863e...     deposit
# 259900   0x2dc0a5f7359297fbf24fb88665f59aa28e86b257863e...  collateral
# 893999   0xa1c814bc812a415d347d55aea4e01b8371aef178647b...     deposit
# 259899   0xa1c814bc812a415d347d55aea4e01b8371aef178647b...  collateral
# 893998   0x0ec4eb191b1167f35abbeca76e33e8d2729c2e41be13...     deposit
# 259898   0x0ec4eb191b1167f35abbeca76e33e8d2729c2e41be13...  collateral
#
#             timestamp                                        user  \
# 21       1.606925e+09  0x39d637737cc76c5849a52c7d3b872a1eb22aa71c
# 18       1.606925e+09  0x39d637737cc76c5849a52c7d3b872a1eb22aa71c
# 17       1.606924e+09  0x39d637737cc76c5849a52c7d3b872a1eb22aa71c
# 5        1.606917e+09  0x39d637737cc76c5849a52c7d3b872a1eb22aa71c
# 3        1.606913e+09  0x39d637737cc76c5849a52c7d3b872a1eb22aa71c
# 1780066  1.606906e+09  0x39d637737cc76c5849a52c7d3b872a1eb22aa71c
# 2        1.606905e+09  0x39d637737cc76c5849a52c7d3b872a1eb22aa71c
# 894000   1.606904e+09  0x39d637737cc76c5849a52c7d3b872a1eb22aa71c
# 259900   1.606904e+09  0x39d637737cc76c5849a52c7d3b872a1eb22aa71c
# 893999   1.606904e+09  0x39d637737cc76c5849a52c7d3b872a1eb22aa71c
# 259899   1.606904e+09  0x39d637737cc76c5849a52c7d3b872a1eb22aa71c
# 893998   1.606904e+09  0x39d637737cc76c5849a52c7d3b872a1eb22aa71c
# 259898   1.606904e+09  0x39d637737cc76c5849a52c7d3b872a1eb22aa71c
#
#               userAlias                                  onBehalfOf  \
# 21       Brian Castillo  0x39d637737cc76c5849a52c7d3b872a1eb22aa71c
# 18       Brian Castillo  0xdcd33426ba191383f1c9b431a342498fdac73488
# 17       Brian Castillo  0x39d637737cc76c5849a52c7d3b872a1eb22aa71c
# 5        Brian Castillo  0x39d637737cc76c5849a52c7d3b872a1eb22aa71c
# 3        Brian Castillo  0x39d637737cc76c5849a52c7d3b872a1eb22aa71c
# 1780066  Brian Castillo  0x39d637737cc76c5849a52c7d3b872a1eb22aa71c
# 2        Brian Castillo  0x39d637737cc76c5849a52c7d3b872a1eb22aa71c
# 894000   Brian Castillo  0x39d637737cc76c5849a52c7d3b872a1eb22aa71c
# 259900   Brian Castillo                                         NaN
# 893999   Brian Castillo  0xdcd33426ba191383f1c9b431a342498fdac73488
# 259899   Brian Castillo                                         NaN
# 893998   Brian Castillo  0x39d637737cc76c5849a52c7d3b872a1eb22aa71c
# 259898   Brian Castillo                                         NaN
#
#          onBehalfOfAlias                                        pool reserve  \
# 21        Brian Castillo  0xb53c1a33016b2dc2ff3653530bff1848a515c8c5     UNI
# 18       Tracie Friedman  0xb53c1a33016b2dc2ff3653530bff1848a515c8c5    WETH
# 17        Brian Castillo  0xb53c1a33016b2dc2ff3653530bff1848a515c8c5     YFI
# 5         Brian Castillo  0xb53c1a33016b2dc2ff3653530bff1848a515c8c5    WBTC
# 3         Brian Castillo  0xb53c1a33016b2dc2ff3653530bff1848a515c8c5    AAVE
# 1780066   Brian Castillo  0xb53c1a33016b2dc2ff3653530bff1848a515c8c5    LINK
# 2         Brian Castillo  0xb53c1a33016b2dc2ff3653530bff1848a515c8c5    LINK
# 894000    Brian Castillo  0xb53c1a33016b2dc2ff3653530bff1848a515c8c5    USDT
# 259900               NaN  0xb53c1a33016b2dc2ff3653530bff1848a515c8c5    USDT
# 893999   Tracie Friedman  0xb53c1a33016b2dc2ff3653530bff1848a515c8c5    WETH
# 259899               NaN  0xb53c1a33016b2dc2ff3653530bff1848a515c8c5    WETH
# 893998    Brian Castillo  0xb53c1a33016b2dc2ff3653530bff1848a515c8c5     DAI
# 259898               NaN  0xb53c1a33016b2dc2ff3653530bff1848a515c8c5     DAI
#
#             amount  ...  liquidatorAlias  priceInUsd  borrowRateModeTo  \
# 21        10.00000  ...              NaN         NaN               NaN
# 18         0.10000  ...              NaN         NaN               NaN
# 17         0.00010  ...              NaN         NaN               NaN
# ...
# 5                      NaN              NaN                NaN    NaN
# 3                      NaN              NaN                NaN    NaN
# 1780066                NaN              NaN                NaN    NaN
# 2                      NaN              NaN                NaN    NaN
# 894000                 NaN              NaN                NaN    NaN
# 259900                 NaN              NaN                NaN    NaN
# 893999                 NaN              NaN                NaN    NaN
# 259899                 NaN              NaN                NaN    NaN
# 893998                 NaN              NaN                NaN    NaN
# 259898                 NaN              NaN                NaN    NaN
#
#          totalFee version  deployment
# 21            NaN      V2     Mainnet
# 18            NaN      V2     Mainnet
# 17            NaN      V2     Mainnet
# 5             NaN      V2     Mainnet
# 3             NaN      V2     Mainnet
# 1780066       NaN      V2     Mainnet
# 2             NaN      V2     Mainnet
# 894000        NaN      V2     Mainnet
# 259900        NaN      V2     Mainnet
# 893999        NaN      V2     Mainnet
# 259899        NaN      V2     Mainnet
# 893998        NaN      V2     Mainnet
# 259898        NaN      V2     Mainnet
#
# [13 rows x 35 columns]
# Dynamic Transactions:
#                                                        id        type  \
# 894025  0x24f391b0cfabb77718df725e9700d4134387b7ecc600...     deposit
# 259932  0x24f391b0cfabb77718df725e9700d4134387b7ecc600...  collateral
# 894024  0x9338a176dd5d83a988f4f3e1433e54c369f27f21d0aa...     deposit
# 259931  0x9338a176dd5d83a988f4f3e1433e54c369f27f21d0aa...  collateral
# 894023  0x3494b18562a99af7485ca5663f084b65ea6b1bc1bebc...     deposit
#
#            timestamp                                        user  \
# 894025  1.606927e+09  0x39d637737cc76c5849a52c7d3b872a1eb22aa71c
# 259932  1.606927e+09  0x39d637737cc76c5849a52c7d3b872a1eb22aa71c
# 894024  1.606926e+09  0x39d637737cc76c5849a52c7d3b872a1eb22aa71c
# 259931  1.606926e+09  0x39d637737cc76c5849a52c7d3b872a1eb22aa71c
# 894023  1.606925e+09  0x39d637737cc76c5849a52c7d3b872a1eb22aa71c
#
#              userAlias                                  onBehalfOf  \
# 894025  Brian Castillo  0x5e2f9d998ba3392bad87fa058e4fbd97797edb48
# 259932  Brian Castillo                                         NaN
# 894024  Brian Castillo  0x5e2f9d998ba3392bad87fa058e4fbd97797edb48
# 259931  Brian Castillo                                         NaN
# 894023  Brian Castillo  0x5e2f9d998ba3392bad87fa058e4fbd97797edb48
#
#        onBehalfOfAlias                                        pool reserve  \
# 894025       Kiah Muya  0xb53c1a33016b2dc2ff3653530bff1848a515c8c5     YFI
# 259932             NaN  0xb53c1a33016b2dc2ff3653530bff1848a515c8c5     YFI
# 894024       Kiah Muya  0xb53c1a33016b2dc2ff3653530bff1848a515c8c5    TUSD
# 259931             NaN  0xb53c1a33016b2dc2ff3653530bff1848a515c8c5    TUSD
# 894023       Kiah Muya  0xb53c1a33016b2dc2ff3653530bff1848a515c8c5    USDC
#
#           amount  ...  liquidatorAlias  priceInUsd  borrowRateModeTo  \
# 894025   0.00011  ...              NaN         NaN               NaN
# 259932       NaN  ...              NaN         NaN               NaN
# 894024  49.94298  ...              NaN         NaN               NaN
# 259931       NaN  ...              NaN         NaN               NaN
# 894023  99.88010  ...              NaN         NaN               NaN
#
#        borrowRateModeFrom stableBorrowRate variableBorrowRate target  \
# 894025                NaN              NaN                NaN    NaN
# 259932                NaN              NaN                NaN    NaN
# 894024                NaN              NaN                NaN    NaN
# 259931                NaN              NaN                NaN    NaN
# 894023                NaN              NaN                NaN    NaN
#
#         totalFee version  deployment
# 894025       NaN      V2     Mainnet
# 259932       NaN      V2     Mainnet
# 894024       NaN      V2     Mainnet
# 259931       NaN      V2     Mainnet
# 894023       NaN      V2     Mainnet
#
# [5 rows x 35 columns]
# ----------------------------------------
# IndexID: 0xca0f089461d53b02d58740ab49be362209e2a730a458ceaf23039d83fe01d369
# Static Transactions:
#                                                         id        type  \
# 894024   0x9338a176dd5d83a988f4f3e1433e54c369f27f21d0aa...     deposit
# 259931   0x9338a176dd5d83a988f4f3e1433e54c369f27f21d0aa...  collateral
# 894023   0x3494b18562a99af7485ca5663f084b65ea6b1bc1bebc...     deposit
# 259928   0x3494b18562a99af7485ca5663f084b65ea6b1bc1bebc...  collateral
# 21       0x4191d90940be6bf98bd4b7b9ca2f86d2a1dec44ecbec...      borrow
# 18       0x1f39325b14fb96c93b48f722aa8be2109be88a79a8e9...      borrow
# 17       0xe64d208024d04bbea7100441d5cf5272bcb77f45b30a...      borrow
# 5        0xb287043d2ef102bb10acd5bb8e8a8e4facac3df6c534...      borrow
# 3        0x43136c7aba13c072bb19ed88f8eadf859f0bfb994b42...      borrow
# 1780066  0x4c3338fe9155dbddecca66e077bd8bfe9965ec12e2b0...       repay
# 2        0x1e8f85330edc5005ead7a7ae8c418fbb64df726d4ffc...      borrow
# 894000   0x2dc0a5f7359297fbf24fb88665f59aa28e86b257863e...     deposit
# 259900   0x2dc0a5f7359297fbf24fb88665f59aa28e86b257863e...  collateral
# 893999   0xa1c814bc812a415d347d55aea4e01b8371aef178647b...     deposit
# 259899   0xa1c814bc812a415d347d55aea4e01b8371aef178647b...  collateral
# 893998   0x0ec4eb191b1167f35abbeca76e33e8d2729c2e41be13...     deposit
# 259898   0x0ec4eb191b1167f35abbeca76e33e8d2729c2e41be13...  collateral
#
#             timestamp                                        user  \
# 894024   1.606926e+09  0x39d637737cc76c5849a52c7d3b872a1eb22aa71c
# 259931   1.606926e+09  0x39d637737cc76c5849a52c7d3b872a1eb22aa71c
# 894023   1.606925e+09  0x39d637737cc76c5849a52c7d3b872a1eb22aa71c
# 259928   1.606925e+09  0x39d637737cc76c5849a52c7d3b872a1eb22aa71c
# 21       1.606925e+09  0x39d637737cc76c5849a52c7d3b872a1eb22aa71c
# 18       1.606925e+09  0x39d637737cc76c5849a52c7d3b872a1eb22aa71c
# 17       1.606924e+09  0x39d637737cc76c5849a52c7d3b872a1eb22aa71c
# 5        1.606917e+09  0x39d637737cc76c5849a52c7d3b872a1eb22aa71c
# 3        1.606913e+09  0x39d637737cc76c5849a52c7d3b872a1eb22aa71c
# 1780066  1.606906e+09  0x39d637737cc76c5849a52c7d3b872a1eb22aa71c
# 2        1.606905e+09  0x39d637737cc76c5849a52c7d3b872a1eb22aa71c
# 894000   1.606904e+09  0x39d637737cc76c5849a52c7d3b872a1eb22aa71c
# 259900   1.606904e+09  0x39d637737cc76c5849a52c7d3b872a1eb22aa71c
# 893999   1.606904e+09  0x39d637737cc76c5849a52c7d3b872a1eb22aa71c
# 259899   1.606904e+09  0x39d637737cc76c5849a52c7d3b872a1eb22aa71c
# 893998   1.606904e+09  0x39d637737cc76c5849a52c7d3b872a1eb22aa71c
# 259898   1.606904e+09  0x39d637737cc76c5849a52c7d3b872a1eb22aa71c
#
#               userAlias                                  onBehalfOf  \
# 894024   Brian Castillo  0x5e2f9d998ba3392bad87fa058e4fbd97797edb48
# 259931   Brian Castillo                                         NaN
# 894023   Brian Castillo  0x5e2f9d998ba3392bad87fa058e4fbd97797edb48
# 259928   Brian Castillo                                         NaN
# 21       Brian Castillo  0x39d637737cc76c5849a52c7d3b872a1eb22aa71c
# 18       Brian Castillo  0xdcd33426ba191383f1c9b431a342498fdac73488
# 17       Brian Castillo  0x39d637737cc76c5849a52c7d3b872a1eb22aa71c
# 5        Brian Castillo  0x39d637737cc76c5849a52c7d3b872a1eb22aa71c
# 3        Brian Castillo  0x39d637737cc76c5849a52c7d3b872a1eb22aa71c
# 1780066  Brian Castillo  0x39d637737cc76c5849a52c7d3b872a1eb22aa71c
# 2        Brian Castillo  0x39d637737cc76c5849a52c7d3b872a1eb22aa71c
# 894000   Brian Castillo  0x39d637737cc76c5849a52c7d3b872a1eb22aa71c
# 259900   Brian Castillo                                         NaN
# 893999   Brian Castillo  0xdcd33426ba191383f1c9b431a342498fdac73488
# 259899   Brian Castillo                                         NaN
# 893998   Brian Castillo  0x39d637737cc76c5849a52c7d3b872a1eb22aa71c
# 259898   Brian Castillo                                         NaN
#
#          onBehalfOfAlias                                        pool reserve  \
# 894024         Kiah Muya  0xb53c1a33016b2dc2ff3653530bff1848a515c8c5    TUSD
# 259931               NaN  0xb53c1a33016b2dc2ff3653530bff1848a515c8c5    TUSD
# 894023         Kiah Muya  0xb53c1a33016b2dc2ff3653530bff1848a515c8c5    USDC
# 259928               NaN  0xb53c1a33016b2dc2ff3653530bff1848a515c8c5    USDC
# 21        Brian Castillo  0xb53c1a33016b2dc2ff3653530bff1848a515c8c5     UNI
# 18       Tracie Friedman  0xb53c1a33016b2dc2ff3653530bff1848a515c8c5    WETH
# 17        Brian Castillo  0xb53c1a33016b2dc2ff3653530bff1848a515c8c5     YFI
# 5         Brian Castillo  0xb53c1a33016b2dc2ff3653530bff1848a515c8c5    WBTC
# 3         Brian Castillo  0xb53c1a33016b2dc2ff3653530bff1848a515c8c5    AAVE
# 1780066   Brian Castillo  0xb53c1a33016b2dc2ff3653530bff1848a515c8c5    LINK
# 2         Brian Castillo  0xb53c1a33016b2dc2ff3653530bff1848a515c8c5    LINK
# 894000    Brian Castillo  0xb53c1a33016b2dc2ff3653530bff1848a515c8c5    USDT
# 259900               NaN  0xb53c1a33016b2dc2ff3653530bff1848a515c8c5    USDT
# 893999   Tracie Friedman  0xb53c1a33016b2dc2ff3653530bff1848a515c8c5    WETH
# 259899               NaN  0xb53c1a33016b2dc2ff3653530bff1848a515c8c5    WETH
# 893998    Brian Castillo  0xb53c1a33016b2dc2ff3653530bff1848a515c8c5     DAI
# 259898               NaN  0xb53c1a33016b2dc2ff3653530bff1848a515c8c5     DAI
#
#             amount  ...  liquidatorAlias  priceInUsd  borrowRateModeTo  \
# 894024    49.94298  ...              NaN         NaN               NaN
# 259931         NaN  ...              NaN         NaN               NaN
# 894023    99.88010  ...              NaN         NaN               NaN
# 259928         NaN  ...              NaN         NaN               NaN
# 21        10.00000  ...              NaN         NaN               NaN
# 18         0.10000  ...              NaN         NaN               NaN
# 17         0.00010  ...              NaN         NaN               NaN
# 5          0.00001  ...              NaN         NaN               NaN
# 3          0.05000  ...              NaN         NaN               NaN
# 1780066    1.00000  ...              NaN   12.761559               NaN
# 2          1.00000  ...              NaN         NaN               NaN
# 894000   250.00000  ...              NaN         NaN               NaN
# 259900         NaN  ...              NaN         NaN               NaN
# 893999     0.50000  ...              NaN         NaN               NaN
# 259899         NaN  ...              NaN         NaN               NaN
# 893998   100.00000  ...              NaN         NaN               NaN
# 259898         NaN  ...              NaN         NaN               NaN
#
#         borrowRateModeFrom stableBorrowRate variableBorrowRate target  \
# 894024                 NaN              NaN                NaN    NaN
# 259931                 NaN              NaN                NaN    NaN
# 894023                 NaN              NaN                NaN    NaN
# 259928                 NaN              NaN                NaN    NaN
# 21                     NaN              NaN                NaN    NaN
# 18                     NaN              NaN                NaN    NaN
# 17                     NaN              NaN                NaN    NaN
# 5                      NaN              NaN                NaN    NaN
# 3                      NaN              NaN                NaN    NaN
# 1780066                NaN              NaN                NaN    NaN
# 2                      NaN              NaN                NaN    NaN
# 894000                 NaN              NaN                NaN    NaN
# 259900                 NaN              NaN                NaN    NaN
# 893999                 NaN              NaN                NaN    NaN
# 259899                 NaN              NaN                NaN    NaN
# 893998                 NaN              NaN                NaN    NaN
# 259898                 NaN              NaN                NaN    NaN
#
#          totalFee version  deployment
# 894024        NaN      V2     Mainnet
# 259931        NaN      V2     Mainnet
# 894023        NaN      V2     Mainnet
# 259928        NaN      V2     Mainnet
# 21            NaN      V2     Mainnet
# 18            NaN      V2     Mainnet
# 17            NaN      V2     Mainnet
# 5             NaN      V2     Mainnet
# 3             NaN      V2     Mainnet
# 1780066       NaN      V2     Mainnet
# 2             NaN      V2     Mainnet
# 894000        NaN      V2     Mainnet
# 259900        NaN      V2     Mainnet
# 893999        NaN      V2     Mainnet
# 259899        NaN      V2     Mainnet
# 893998        NaN      V2     Mainnet
# 259898        NaN      V2     Mainnet
#
# [17 rows x 35 columns]
# Dynamic Transactions:
#                                                         id        type  \
# 1780069  0xa5ba3a7c3267714aed505ce871df2e5719c8247ac913...       repay
# 894026   0x994098978ce2691bbf6d71e4df9ae936997a5e9453a8...     deposit
# 259937   0x994098978ce2691bbf6d71e4df9ae936997a5e9453a8...  collateral
# 894025   0x24f391b0cfabb77718df725e9700d4134387b7ecc600...     deposit
# 259932   0x24f391b0cfabb77718df725e9700d4134387b7ecc600...  collateral
#
#             timestamp                                        user  \
# 1780069  1.606927e+09  0x39d637737cc76c5849a52c7d3b872a1eb22aa71c
# 894026   1.606927e+09  0x39d637737cc76c5849a52c7d3b872a1eb22aa71c
# 259937   1.606927e+09  0x39d637737cc76c5849a52c7d3b872a1eb22aa71c
# 894025   1.606927e+09  0x39d637737cc76c5849a52c7d3b872a1eb22aa71c
# 259932   1.606927e+09  0x39d637737cc76c5849a52c7d3b872a1eb22aa71c
#
#               userAlias                                  onBehalfOf  \
# 1780069  Brian Castillo  0x39d637737cc76c5849a52c7d3b872a1eb22aa71c
# 894026   Brian Castillo  0x5e2f9d998ba3392bad87fa058e4fbd97797edb48
# 259937   Brian Castillo                                         NaN
# 894025   Brian Castillo  0x5e2f9d998ba3392bad87fa058e4fbd97797edb48
# 259932   Brian Castillo                                         NaN
#
#         onBehalfOfAlias                                        pool reserve  \
# 1780069  Brian Castillo  0xb53c1a33016b2dc2ff3653530bff1848a515c8c5     YFI
# 894026        Kiah Muya  0xb53c1a33016b2dc2ff3653530bff1848a515c8c5    AAVE
# 259937              NaN  0xb53c1a33016b2dc2ff3653530bff1848a515c8c5    AAVE
# 894025        Kiah Muya  0xb53c1a33016b2dc2ff3653530bff1848a515c8c5     YFI
# 259932              NaN  0xb53c1a33016b2dc2ff3653530bff1848a515c8c5     YFI
#
#            amount  ...  liquidatorAlias  priceInUsd  borrowRateModeTo  \
# 1780069  0.000100  ...              NaN  20329.0512               NaN
# 894026   0.675999  ...              NaN         NaN               NaN
# 259937        NaN  ...              NaN         NaN               NaN
# 894025   0.000110  ...              NaN         NaN               NaN
# 259932        NaN  ...              NaN         NaN               NaN
#
#         borrowRateModeFrom stableBorrowRate variableBorrowRate target  \
# 1780069                NaN              NaN                NaN    NaN
# 894026                 NaN              NaN                NaN    NaN
# 259937                 NaN              NaN                NaN    NaN
# 894025                 NaN              NaN                NaN    NaN
# 259932                 NaN              NaN                NaN    NaN
#
#          totalFee version  deployment
# 1780069       NaN      V2     Mainnet
# 894026        NaN      V2     Mainnet
# 259937        NaN      V2     Mainnet
# 894025        NaN      V2     Mainnet
# 259932        NaN      V2     Mainnet
#
# [5 rows x 35 columns]
# ----------------------------------------

# %%
from transformers import BertModel, BertTokenizer
import torch

# Load pre-trained model for embedding
model_path = "./output_aave/final-model"  # Replace with your model directory
model = BertModel.from_pretrained(model_path)  # Use your custom model class if necessary
model.eval()

# Tokenizer
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
# Out:
# Some weights of BertModel were not initialized from the model checkpoint at ./output_aave/final-model and are newly initialized: ['embeddings.LayerNorm.bias', 'embeddings.LayerNorm.weight', 'embeddings.position_embeddings.weight', 'embeddings.token_type_embeddings.weight', 'embeddings.word_embeddings.weight', 'encoder.layer.0.attention.output.LayerNorm.bias', 'encoder.layer.0.attention.output.LayerNorm.weight', 'encoder.layer.0.attention.output.dense.bias', 'encoder.layer.0.attention.output.dense.weight', 'encoder.layer.0.attention.self.key.bias', 'encoder.layer.0.attention.self.key.weight', 'encoder.layer.0.attention.self.query.bias', 'encoder.layer.0.attention.self.query.weight', 'encoder.layer.0.attention.self.value.bias', 'encoder.layer.0.attention.self.value.weight', 'encoder.layer.0.intermediate.dense.bias', 'encoder.layer.0.intermediate.dense.weight', 'encoder.layer.0.output.LayerNorm.bias', 'encoder.layer.0.output.LayerNorm.weight', 'encoder.layer.0.output.dense.bias', 'encoder.layer.0.output.dense.weight', 'encoder.layer.1.attention.output.LayerNorm.bias', 'encoder.layer.1.attention.output.LayerNorm.weight', 'encoder.layer.1.attention.output.dense.bias', 'encoder.layer.1.attention.output.dense.weight', 'encoder.layer.1.attention.self.key.bias', 'encoder.layer.1.attention.self.key.weight', 'encoder.layer.1.attention.self.query.bias', 'encoder.layer.1.attention.self.query.weight', 'encoder.layer.1.attention.self.value.bias', 'encoder.layer.1.attention.self.value.weight', 'encoder.layer.1.intermediate.dense.bias', 'encoder.layer.1.intermediate.dense.weight', 'encoder.layer.1.output.LayerNorm.bias', 'encoder.layer.1.output.LayerNorm.weight', 'encoder.layer.1.output.dense.bias', 'encoder.layer.1.output.dense.weight', 'encoder.layer.10.attention.output.LayerNorm.bias', 'encoder.layer.10.attention.output.LayerNorm.weight', 'encoder.layer.10.attention.output.dense.bias', 'encoder.layer.10.attention.output.dense.weight', 'encoder.layer.10.attention.self.key.bias', 'encoder.layer.10.attention.self.key.weight', 'encoder.layer.10.attention.self.query.bias', 'encoder.layer.10.attention.self.query.weight', 'encoder.layer.10.attention.self.value.bias', 'encoder.layer.10.attention.self.value.weight', 'encoder.layer.10.intermediate.dense.bias', 'encoder.layer.10.intermediate.dense.weight', 'encoder.layer.10.output.LayerNorm.bias', 'encoder.layer.10.output.LayerNorm.weight', 'encoder.layer.10.output.dense.bias', 'encoder.layer.10.output.dense.weight', 'encoder.layer.11.attention.output.LayerNorm.bias', 'encoder.layer.11.attention.output.LayerNorm.weight', 'encoder.layer.11.attention.output.dense.bias', 'encoder.layer.11.attention.output.dense.weight', 'encoder.layer.11.attention.self.key.bias', 'encoder.layer.11.attention.self.key.weight', 'encoder.layer.11.attention.self.query.bias', 'encoder.layer.11.attention.self.query.weight', 'encoder.layer.11.attention.self.value.bias', 'encoder.layer.11.attention.self.value.weight', 'encoder.layer.11.intermediate.dense.bias', 'encoder.layer.11.intermediate.dense.weight', 'encoder.layer.11.output.LayerNorm.bias', 'encoder.layer.11.output.LayerNorm.weight', 'encoder.layer.11.output.dense.bias', 'encoder.layer.11.output.dense.weight', 'encoder.layer.2.attention.output.LayerNorm.bias', 'encoder.layer.2.attention.output.LayerNorm.weight', 'encoder.layer.2.attention.output.dense.bias', 'encoder.layer.2.attention.output.dense.weight', 'encoder.layer.2.attention.self.key.bias', 'encoder.layer.2.attention.self.key.weight', 'encoder.layer.2.attention.self.query.bias', 'encoder.layer.2.attention.self.query.weight', 'encoder.layer.2.attention.self.value.bias', 'encoder.layer.2.attention.self.value.weight', 'encoder.layer.2.intermediate.dense.bias', 'encoder.layer.2.intermediate.dense.weight', 'encoder.layer.2.output.LayerNorm.bias', 'encoder.layer.2.output.LayerNorm.weight', 'encoder.layer.2.output.dense.bias', 'encoder.layer.2.output.dense.weight', 'encoder.layer.3.attention.output.LayerNorm.bias', 'encod ...
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
from sentence_transformers import SentenceTransformer
import torch

# Load pre-trained Sentence-BERT model for embedding
model = SentenceTransformer('all-MiniLM-L6-v2')

# %%
embedding_samples = []

for sample in samples:
    dynamic_transactions = sample['dynamic_transactions']
    if not dynamic_transactions.empty:
        # Use all columns from dynamic_transactions
        all_columns = dynamic_transactions.columns
        
        # Prepare text input for embedding using all columns
        transaction_text = " ".join(dynamic_transactions[all_columns].astype(str).agg(' '.join, axis=1))
        
        # Generate embedding using the Sentence-BERT model
        embedding = model.encode(transaction_text)
        
        # Append the embedding sample to the list
        embedding_sample = {
            'id': sample['indexID'],
            'timeDiff': sample['indexTime'],
            'status': sample['indexStatus'],
            'embedding': embedding
        }
        embedding_samples.append(embedding_sample)
    else:
        print(f"Empty or invalid input for indexID {sample['indexID']}, skipping...")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[20], line 13
#      10 transaction_text = " ".join(dynamic_transactions[all_columns].astype(str).agg(' '.join, axis=1))
#      12 # Generate embedding using the Sentence-BERT model
# ---> 13 embedding = model.encode(transaction_text)
#      15 # Append the embedding sample to the list
#      16 embedding_sample = {
#      17     'id': sample['indexID'],
#      18     'timeDiff': sample['indexTime'],
#      19     'status': sample['indexStatus'],
#      20     'embedding': embedding
#      21 }
#
# File ~/.conda/envs/new_env/lib/python3.9/site-packages/torch/nn/modules/module.py:1729, in Module.__getattr__(self, name)
#    1727     if name in modules:
#    1728         return modules[name]
# -> 1729 raise AttributeError(f"'{type(self).__name__}' object has no attribute '{name}'")
#
# AttributeError: 'BertModel' object has no attribute 'encode'

# %%
# Create final dataset with embeddings
final_dataset = pd.DataFrame(embedding_samples)
print(final_dataset.head())
# Out:
#                                                   id      timeDiff  status  \
# 0  0x0c66ade8a26d0bedbc967005a75a00028cebf222ec45...  1.606837e+09     0.0
# 1  0x25f636e7b49a599c765bcdac00853265ac76a5921953...  1.606841e+09     0.0
# 2  0x17869b1999e221cb74ab4fc8c9f7087097e6e27b50dd...  1.606841e+09     0.0
# 3  0xae1083a26ffc90a681fc856b9bb087e37a16c037227a...  1.606913e+09     0.0
# 4  0xd12cbbad05aa4b7dbcf62ee862bf07c73ddfca58f035...  1.606918e+09     0.0
#
#                                            embedding
# 0  [0.001982082, -0.006319259, -0.05993434, -0.10...
# 1  [0.019646313, -0.016742138, -0.05178565, -0.09...
# 2  [0.011911144, -0.026023526, -0.057819903, -0.0...
# 3  [0.033537854, -0.020683905, -0.057182007, -0.1...
# 4  [-0.018207029, -0.027614292, -0.07083733, -0.0...

# %%
import os
save_path = "data"
final_dataset_path = os.path.join(save_path, "final_dataset.csv")
final_dataset.to_csv(final_dataset_path, index=False)
print(f"Final dataset saved at: {final_dataset_path}")
# Out:
# Final dataset saved at: data/final_dataset.csv
