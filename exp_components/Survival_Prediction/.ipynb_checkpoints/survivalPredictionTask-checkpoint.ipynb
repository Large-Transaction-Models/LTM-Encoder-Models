# %%
import numpy as np
import pandas as pd
import pyreadr

exp_name = "aave_v2_mainnet_small"
checkpoint = 106880

if checkpoint == -1:
    

data_path = f"/data/IDEA_DeFi_Research/Data/Lending_Protocols/Aave/V2/Mainnet/preprocessed_user_market_time/preloaded_16_None/checkpoints/{exp_name}/checkpoint-106880/"
# Load embeddings
embeddings = np.load(f"{data_path}cls_embeddings.npy")
embedding_ids = np.load(f"{data_path}cls_embeddings_row_ids.npy")
data_df = pd.DataFrame(embeddings)
data_df["id"] = embedding_ids
# Load labels (assuming labels file is available)
labels_df = pyreadr.read_r(f"/data/IDEA_DeFi_Research/Data/Lending_Protocols/Aave/V2/Mainnet/id_types.rds")[None]

# %%
x_ltm_path = "/data/IDEA_DeFi_Research/Data/Survival_Data/Borrow/X_/"

# %%
data_df
# Out:
#                0         1         2         3         4         5         6  \
# 0      -2.187463  1.966442  0.567323 -0.117902 -1.349013 -0.922842 -3.679307
# 1      -2.187463  1.966442  0.567323 -0.117902 -1.349013 -0.922842 -3.679307
# 2      -2.187463  1.966442  0.567323 -0.117902 -1.349013 -0.922842 -3.679307
# 3      -2.187463  1.966442  0.567323 -0.117902 -1.349013 -0.922842 -3.679307
# 4      -2.187463  1.966442  0.567323 -0.117902 -1.349013 -0.922842 -3.679307
# ...          ...       ...       ...       ...       ...       ...       ...
# 407149  0.479367  0.036712 -0.107703  0.691946  0.298308 -0.402527  1.238014
# 407150  0.151633  1.923453  0.090868 -0.389037 -1.419791 -0.998851 -0.002963
# 407151  0.051235  0.783678 -0.891012 -0.170514 -0.568927  0.253490  0.592389
# 407152 -0.323938  1.167161  0.293185  0.524681  0.384482 -0.701898  0.082046
# 407153 -2.187463  1.966442  0.567323 -0.117902 -1.349013 -0.922842 -3.679307
#
#                7         8         9  ...      1991      1992      1993  \
# 0       0.621195 -0.191399 -2.465237  ...  0.906208  2.427316 -0.186432
# 1       0.621195 -0.191399 -2.465237  ...  0.906208  2.427316 -0.186432
# 2       0.621195 -0.191399 -2.465237  ...  0.906208  2.427316 -0.186432
# 3       0.621195 -0.191399 -2.465237  ...  0.906208  2.427316 -0.186432
# 4       0.621195 -0.191399 -2.465237  ...  0.906208  2.427316 -0.186432
# ...          ...       ...       ...  ...       ...       ...       ...
# 407149 -0.940181  0.399639 -0.170412  ...  0.777124  0.967911  0.253317
# 407150 -0.568901 -0.022018 -0.014800  ... -0.179461  1.550680  0.701737
# 407151  0.249721 -0.415150 -0.465327  ...  0.086693  1.339081 -0.987682
# 407152  1.692535 -1.816106  0.970262  ... -0.052105  0.632201  1.109502
# 407153  0.621195 -0.191399 -2.465237  ...  0.906208  2.427316 -0.186432
#
#             1994      1995      1996      1997      1998      1999  \
# 0      -0.958578 -0.060118 -1.423200  0.874332  0.300801 -0.056029
# 1      -0.958578 -0.060118 -1.423200  0.874332  0.300801 -0.056029
# 2      -0.958578 -0.060118 -1.423200  0.874332  0.300801 -0.056029
# 3      -0.958578 -0.060118 -1.423200  0.874332  0.300801 -0.056029
# 4      -0.958578 -0.060118 -1.423200  0.874332  0.300801 -0.056029
# ...          ...       ...       ...       ...       ...       ...
# 407149  0.108057 -0.592254  0.587357 -0.102640 -2.066707  0.711939
# 407150 -0.373511 -0.554681 -1.471741  0.292869 -0.508854  0.823571
# 407151 -0.503964  0.038987  0.965448  0.849246 -1.565328  0.464640
# 407152 -0.541235  0.386678 -1.037603  2.104779 -0.996587  0.599513
# 407153 -0.958578 -0.060118 -1.423200  0.874332  0.300801 -0.056029
#
#                                                        id
# 0       0x3fec3516c8085e089d408562dd3f9ca1bbbc5b0eb4ea...
# 1       0x59a33c72e045d762a069ddfe10540ddc1b521cbd27e1...
# 2       0x3f33d1fd27aee4e4ff56ef10ab6280729d187cd159a3...
# 3       0x229cad41b44765888cf7d54aaf3f47e998e0a9c8caaf...
# 4       0x336226751c45747c068f70101e039966c1269d949fcb...
# ...                                                   ...
# 407149  0xc03469ce4d3733d01ad139458b8de1b7214c0a9c3a0e...
# 407150  0x40d50eba0a87054bcef6c3de2a242275bf851d62406f...
# 407151  0x75e92a5f1a69445c5b034db1b1481b2968bc87d37fca...
# 407152  0x51355e44492d51622805dbbd87921a38bdf77818a03a...
# 407153  0x60a66f8773e8b4edeb0a03348c19e68adc4f214b0c7c...
#
# [407154 rows x 2001 columns]

# %%
# Step 1: Merge the two dataframes on 'id'
merged_df = pd.merge(data_df, labels_df, on='id', how='inner')

# %%
merged_df
# Out:
#                 0         1         2         3         4         5         6  \
# 0       -2.187463  1.966442  0.567323 -0.117902 -1.349013 -0.922842 -3.679307
# 1       -2.187463  1.966442  0.567323 -0.117902 -1.349013 -0.922842 -3.679307
# 2       -2.187463  1.966442  0.567323 -0.117902 -1.349013 -0.922842 -3.679307
# 3       -2.187463  1.966442  0.567323 -0.117902 -1.349013 -0.922842 -3.679307
# 4       -2.187463  1.966442  0.567323 -0.117902 -1.349013 -0.922842 -3.679307
# ...           ...       ...       ...       ...       ...       ...       ...
# 1001745  0.151633  1.923453  0.090868 -0.389037 -1.419791 -0.998851 -0.002963
# 1001746  0.051235  0.783678 -0.891012 -0.170514 -0.568927  0.253490  0.592389
# 1001747 -0.323938  1.167161  0.293185  0.524681  0.384482 -0.701898  0.082046
# 1001748 -2.187463  1.966442  0.567323 -0.117902 -1.349013 -0.922842 -3.679307
# 1001749 -2.187463  1.966442  0.567323 -0.117902 -1.349013 -0.922842 -3.679307
#
#                 7         8         9  ...      1992      1993      1994  \
# 0        0.621195 -0.191399 -2.465237  ...  2.427316 -0.186432 -0.958578
# 1        0.621195 -0.191399 -2.465237  ...  2.427316 -0.186432 -0.958578
# 2        0.621195 -0.191399 -2.465237  ...  2.427316 -0.186432 -0.958578
# 3        0.621195 -0.191399 -2.465237  ...  2.427316 -0.186432 -0.958578
# 4        0.621195 -0.191399 -2.465237  ...  2.427316 -0.186432 -0.958578
# ...           ...       ...       ...  ...       ...       ...       ...
# 1001745 -0.568901 -0.022018 -0.014800  ...  1.550680  0.701737 -0.373511
# 1001746  0.249721 -0.415150 -0.465327  ...  1.339081 -0.987682 -0.503964
# 1001747  1.692535 -1.816106  0.970262  ...  0.632201  1.109502 -0.541235
# 1001748  0.621195 -0.191399 -2.465237  ...  2.427316 -0.186432 -0.958578
# 1001749  0.621195 -0.191399 -2.465237  ...  2.427316 -0.186432 -0.958578
#
#              1995      1996      1997      1998      1999  \
# 0       -0.060118 -1.423200  0.874332  0.300801 -0.056029
# 1       -0.060118 -1.423200  0.874332  0.300801 -0.056029
# 2       -0.060118 -1.423200  0.874332  0.300801 -0.056029
# 3       -0.060118 -1.423200  0.874332  0.300801 -0.056029
# 4       -0.060118 -1.423200  0.874332  0.300801 -0.056029
# ...           ...       ...       ...       ...       ...
# 1001745 -0.554681 -1.471741  0.292869 -0.508854  0.823571
# 1001746  0.038987  0.965448  0.849246 -1.565328  0.464640
# 1001747  0.386678 -1.037603  2.104779 -0.996587  0.599513
# 1001748 -0.060118 -1.423200  0.874332  0.300801 -0.056029
# 1001749 -0.060118 -1.423200  0.874332  0.300801 -0.056029
#
#                                                         id        type
# 0        0x3fec3516c8085e089d408562dd3f9ca1bbbc5b0eb4ea...  collateral
# 1        0x59a33c72e045d762a069ddfe10540ddc1b521cbd27e1...  collateral
# 2        0x3f33d1fd27aee4e4ff56ef10ab6280729d187cd159a3...  collateral
# 3        0x3f33d1fd27aee4e4ff56ef10ab6280729d187cd159a3...  collateral
# 4        0x229cad41b44765888cf7d54aaf3f47e998e0a9c8caaf...  collateral
# ...                                                    ...         ...
# 1001745  0x40d50eba0a87054bcef6c3de2a242275bf851d62406f...       repay
# 1001746  0x75e92a5f1a69445c5b034db1b1481b2968bc87d37fca...      borrow
# 1001747  0x51355e44492d51622805dbbd87921a38bdf77818a03a...       repay
# 1001748  0x60a66f8773e8b4edeb0a03348c19e68adc4f214b0c7c...  collateral
# 1001749  0x60a66f8773e8b4edeb0a03348c19e68adc4f214b0c7c...     deposit
#
# [1001750 rows x 2002 columns]

# %%
# Step 2: Filter to just "borrow" transactions
borrow_df = merged_df[merged_df["type"] == "borrow"]

# Drop the 'type' column since it's no longer needed
borrow_embeddings_df = borrow_df.drop(columns=['type'])

# Inspect the result
print(borrow_embeddings_df.head())
# Out:
#            0         1         2         3         4         5         6  \
# 10 -2.187463  1.966442  0.567323 -0.117902 -1.349013 -0.922842 -3.679307
# 48 -2.187463  1.966442  0.567323 -0.117902 -1.349013 -0.922842 -3.679307
# 52  0.381682 -0.779289  0.533884  0.652164 -0.693163 -2.175180 -0.782063
# 56 -0.321027 -1.464982  0.711434 -0.512248 -0.451726 -2.109847 -1.112712
# 58  0.801739 -1.013605 -0.041028 -0.837231 -0.648321 -2.415714  0.198400
#
#            7         8         9  ...      1991      1992      1993      1994  \
# 10  0.621195 -0.191399 -2.465237  ...  0.906208  2.427316 -0.186432 -0.958578
# 48  0.621195 -0.191399 -2.465237  ...  0.906208  2.427316 -0.186432 -0.958578
# 52 -0.372636  0.042196 -0.850363  ...  1.153532  0.667918 -0.237744  1.080757
# 56 -1.636460  0.144966 -0.497535  ...  0.723306 -0.276735 -0.589329 -0.178017
# 58 -0.222834  0.363583 -2.658323  ...  0.308582  0.909020  1.441490  0.764158
#
#         1995      1996      1997      1998      1999  \
# 10 -0.060118 -1.423200  0.874332  0.300801 -0.056029
# 48 -0.060118 -1.423200  0.874332  0.300801 -0.056029
# 52  0.338386  1.790335  0.082070  0.959275  0.207165
# 56 -0.258430  1.568239  0.415626  0.443973  0.709219
# 58 -1.256364  0.426787  1.215223  0.320224  1.472714
#
#                                                    id
# 10  0x0ee78a520958780577a64993f01050cc32e80bd0bad9...
# 48  0x8c40adab53958c9be49fa89fd31fd245aa4b8fce4b94...
# 52  0x4b7e228fe67cca01988bae32d0ecd199a6073d27a0e6...
# 56  0xc6aeb3aa97cee9ccd0231d5f03688a1313a940fa6637...
# 58  0x788994166c02e0678a2f2513f07c2f5c7b78edebe799...
#
# [5 rows x 2001 columns]

# %%
merged_df.to_csv("~/merged_df.csv")

# %%
pyreadr.write_rds(f"~/embeddings.rds", data_df)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~/.conda/envs/greena12/lib/python3.10/platform.py:906, in system()
#     902     return _uname_cache
#     904 ### Direct interfaces to some of the uname() return values
# --> 906 def system():
#     908     """ Returns the system/OS name, e.g. 'Linux', 'Windows' or 'Java'.
#     909
#     910         An empty string is returned if the value cannot be determined.
#     911
#     912     """
#     913     return uname().system
#
# KeyboardInterrupt:
# Exception ignored in: 'pyreadr.librdata._handle_write'
# Traceback (most recent call last):
#   File "/home/greena12/.conda/envs/greena12/lib/python3.10/platform.py", line 906, in system
#     def system():
# KeyboardInterrupt:
# ---------------------------------------------------------------------------
# LibrdataError                             Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 pyreadr.write_rds(f"~/embeddings.rds", data_df)
#
# File ~/.conda/envs/greena12/lib/python3.10/site-packages/pyreadr/pyreadr.py:206, in write_rds(path, df, dateformat, datetimeformat, compress)
#     203 filename_bytes = os.path.expanduser(filename_bytes)
#     205 writer = PyreadrWriter()
# --> 206 writer.write_r(filename_bytes, file_format, df, df_name, dateformat, datetimeformat, compress)
#
# File ~/.conda/envs/greena12/lib/python3.10/site-packages/pyreadr/_pyreadr_writer.py:230, in PyreadrWriter.write_r(self, path, file_format, df, df_name, dateformat, datetimeformat, compress)
#     228     curtype = librdata_types[column]
#     229     for row_indx, val in enumerate(tcol):
# --> 230         self.insert_value(row_indx, indx, val, curtype)
#     232 self.close()
#     234 if compress:
#
# File ~/.conda/envs/greena12/lib/python3.10/site-packages/pyreadr/librdata.pyx:367, in pyreadr.librdata.Writer.insert_value()
#
# LibrdataError: Unable to write to file
